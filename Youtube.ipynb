# %%
from googleapiclient.discovery import build
import pymongo
import mysql.connector
import pandas as pd
from datetime import datetime
import isodate
import streamlit as st

# %%
# API key coccection :

def Api_connect():
    Api_ID = "AIzaSyBMk7WfFhkePxno4rdqt7DAhdRJtzsWm5Q"
    api_service_name = "youtube"
    api_version = "v3"
    
    youtube = build(api_service_name, api_version, developerKey= Api_ID)
    return youtube 

youtube = Api_connect()

# %%
# Function for getting Channel information :

def get_channel_info(channel_id):

    request = youtube.channels().list(part = "snippet,ContentDetails,statistics",
                                      id = channel_id)
    response = request.execute()
    
    for i in response['items']:
        data =dict(Channel_Name = i['snippet']['title'],
                   Channel_ID = i['id'],
                   Subscribers = i['statistics']['subscriberCount'],
                   Views_Count = i['statistics']['viewCount'],
                   Video_Count = i['statistics']['videoCount'],
                   Channel_Description = i['snippet']['description'],
                   Playlist_ID = i['contentDetails']['relatedPlaylists']['uploads'] )
        
    return data

# %%
channel_details = get_channel_info('UCvppRuz_VW0x2a5BEAphhNg')
channel_details
# Out:
# {'Channel_Name': 'English Pesalam',
#  'Channel_ID': 'UCvppRuz_VW0x2a5BEAphhNg',
#  'Subscribers': '576000',
#  'Views_Count': '51190056',
#  'Video_Count': '554',
#  'Channel_Description': 'Hi Friends 😃😃\n\nlearn English through Tamil from this Channel. watch this Channel and learn to speak English language fluently. daily English sentences for you. English to Tamil translation.👍👍\n\n#spokenenglish #englishpesalam #english #learnenglish #shorts #shortsfeed',
#  'Playlist_ID': 'UUvppRuz_VW0x2a5BEAphhNg'}

# %%
# Function for getting Video IDs :

def get_videos_ids(channel_id):

    video_ids = []
    
    request = youtube.channels().list(id = channel_id,
                                      part = 'contentDetails')
    response = request.execute()
    
    Playlist_ID = response['items'][0]['contentDetails']['relatedPlaylists']['uploads']
    
    next_page_token = None
    
    while True :
        response1 = youtube.playlistItems().list(part = 'snippet',
                                                 playlistId = Playlist_ID,
                                                 maxResults = 50,
                                                 pageToken = next_page_token).execute()
        
        for i in range(len(response1['items'])):
            video_ids.append(response1['items'][i]['snippet']['resourceId']['videoId'])
    
        next_page_token = response1.get('nextPageToken')
    
        if next_page_token is None :
            break 
     
    return video_ids

# %%
Video_Ids = get_videos_ids('UC9kKt-14c3tjGJSO_jwPHnA')

# %%
Video_Ids
# Out:
# ['FsmGJxppnlY',
#  'dA4XM5u-6Oc',
#  'G9OEsPZGVWs',
#  '6tGfa9aepz0',
#  'Il-Wd_88fZE',
#  'A4-WwASNAnE',
#  'TDYtHZAaxHw',
#  'MusbnHeGeP8',
#  'UEa9eeClLFI',
#  'TKfiti3_vyY',
#  'PwOrzH4g2Dg',
#  '0ETaOu7yu-Q',
#  '7gNXXeDUhe8',
#  'gckt7y6TqYo',
#  'apekYaY2ZGE',
#  'qUJTkohDOxc',
#  'CP2Me9AUPA0',
#  '78WxtTkcIgI',
#  'Mj4qBRthUZI',
#  '8vjRNzQwdy8',
#  'B06aRs1rvKg',
#  'XHaEuPzOsig',
#  'Hi_CwdFlpKg',
#  'x7Ub1LkrKVE',
#  '2LnOlUvkZ9M',
#  'y6LW8wtGIgM',
#  '877t1yyKwkI',
#  'qFAaBX0OXko',
#  'AnORSQMvbco',
#  'WS-5DtAqymM',
#  'nCYtXDLkBBc',
#  'anQAMsAXVHs',
#  'zPdnlEvWKD0',
#  '2Y6PRWVk1Ng',
#  'w1aYdmAgrck',
#  'sUb8SP_MEro',
#  'bZ4z3M8lfAc',
#  'e4msUutQw_s',
#  'aP7o5jKRmMM',
#  'VXUpCXrwpOQ',
#  '0pGntFqkEUk',
#  'cgKDZpL4oHM',
#  'BMIWwPtO5C0',
#  'O-XZXza-7PE',
#  'twwZWmG14Bk',
#  'yoqssMqYRco',
#  'GA3JGMHH7cU',
#  'prI5oz_GRes',
#  'hUAWzRuCtgs',
#  'R5CiVduw518',
#  'rrYNBwihi9w',
#  '96YgBXe17No',
#  'VYieK-DBLyk',
#  '-yknBskYJps',
#  '7xzvKIt1Yrw',
#  'eUhhKkK4el0',
#  'raguvLZ0wK0',
#  'qsoIE6zEdLs',
#  'jACAQrE34eY',
#  'mQ08eT9zHyo',
#  'RNxHtyslru0',
#  '2VJSARfTt6s',
#  '2mnzSm7vxLk',
#  'JBA8Et2cPGg',
#  '47y7ZsQZqaU',
#  '20DL10QGc4c',
#  'JmgH7d1nQiA',
#  'f3o_9JtaZgM',
#  'UK5XvFMuguo',
#  'RAlMj6Pht9g',
#  'JSnlZJvPQhc',
#  '9aPROBCV9mI',
#  'GNf4RI22qdg',
#  'Y0uJHyc89qA',
#  'D2os6zM30ho',
#  'TBQRn-FuLNo',
#  'IAoCf8mGlIw',
#  'fuYQIzRffPg',
#  'raLzRgUr8uk',
#  'SEWiVscDmcY',
#  'QgrEb7nlWuU',
#  'viT6gaAevoc',
#  '7j5A2Sp4yeM',
#  '6rIUyuAq4ZY',
#  'olpQIn3727Q',
#  'u7DzlP_WLqE',
#  '9DonHKL3sEE',
#  'vqMsGXY1gcg',
#  'GdyKnSsSgKc',
#  'xduCld-4PjA',
#  '0glNBWTsMPQ',
#  'a6Ol63FkZ-E',
#  'NB9DEv6kxfE',
#  'TKjDtGsqtSw',
#  'SrR7aFbHU2k',
#  'WrmA7REn0yI',
#  '_o2KHz-8iS4',
#  '1fF9wrzhzFY',
#  'cvOEHjIUzNI',
#  'HZKE1U3-h6w',
#  'IFMXmgCJOXg',
#  'J2LasdZr3KQ',
#  'P7Gc4pojSaQ',
#  'WkDENcCQH7Q',
#  'IWUaczMaq88',
#  'jSQwiWfGK3c',
#  'GVzAwBF3g1M',
#  'Dc6BOTApQ7g',
#  '2YFSUOfvuSU',
#  'fryzsbh_4Uw',
#  'bWap-dkDFB0',
#  'Yci85KhXLdg',
#  'FkbMkK_OWQk',
#  'xEy_cI7HuW0',
#  'n-zir72hy9w',
#  'H3NRRCVEk4M',
#  'QgffvCmdMVU',
#  'NT3ydRjInJ0',
#  'ieqPKg568uY',
#  '77B2EVaIy2c',
#  'FERwgUIhP1Q',
#  '5XaVZdkJX9s',
#  'r7PkD93ZPOI',
#  '-zOizrQvgAw',
#  'yo7j_NfTQ0s',
#  'ANUrpsdyT2w',
#  'wiBZ4WM-28Q',
#  'nEF629kxHs8',
#  'ldE9Zzq9fwc',
#  'osSnhlITDZk',
#  'SSui-AF12zo',
#  'ETddGpMTb9A',
#  'CDx_g9E9kJE',
#  'Usi7wj9aOTk',
#  '1adyn5JUgqM',
#  'fM_qstFSX5k',
#  '9mfou0rLI9I',
#  'nZpOCmO_C_k',
#  'tPSIamauDDc',
#  'IufWROHAQrg',
#  '7eG0ZUbr3yE',
#  'vKk5FEwvWT4',
#  'mnX0aGuhNGk',
#  '6LB3D8OJ8HI',
#  '2XNhdKf_zNs',
#  'aXf6I76Xij0',
#  'mKRX43sAcV0',
#  'FUmlItNfZWo',
#  'gYHSjpoLJOI',
#  '_Q0pl4X3T-Q',
#  'HSUrhjLOpX0',
#  '3jcTXvQMwfI',
#  'xn9n0nvOMZo',
#  'HVgDJoEs15s',
#  'k1V_Pf8o-gc',
#  'PrJDSqHME4A',
#  'LtL2o1fMPRk',
#  'G3yjSAz6B4w',
#  '_vvzDcs7CeE',
#  'gVkQ9lgxmLw',
#  '4-yjDSMKSjM',
#  '9UkPS-WPFLQ',
#  '74EMZCEnGt0',
#  'ftGFKNsRKpU',
#  'A7U6B7bkTmY',
#  'IfGIq6R7Vyg',
#  'mgV8YODTIMk',
#  'IGG0ZaDol3g',
#  'sMMjqvuCb6w',
#  'Q42SjnkAgNE',
#  'E6R92j2LStc',
#  'gNVPDnOGJrY',
#  'mYvuAGVd_ZE']

# %%
# Function for getting Vedio Informations :

def get_video_info(video_ids):

    video_data = []
    for video_id in video_ids:
        request = youtube.videos().list(part = 'snippet,contentDetails,statistics',
                                        id = video_id)
        response = request.execute()
    
        for i in response['items']:
            data = dict(Channel_Name = i['snippet']['channelTitle'],
                        Channel_ID = i['snippet']['channelId'],
                        Video_ID = i['id'],
                        Video_Title = i['snippet']['title'],
                        Thumbnail = i['snippet']['thumbnails']['default']['url'],
                        Description = i['snippet'].get('description'),
                        Published_Date = i['snippet']['publishedAt'],
                        Duration = i['contentDetails']['duration'],
                        Views_Count =i['statistics']['viewCount'],
                        Likes_Count =i['statistics'].get('likeCount'),
                        Comments_Count = i['statistics'].get('commentCount'),
                        Favourite_Count = i['statistics']['favoriteCount'],
                        Definition = i['contentDetails']['definition'],
                        Caption_Status = i['contentDetails']['caption'])
    
            video_data.append(data)

    return video_data

# %%
video_datails = get_video_info(Video_Ids)
video_datails
# Out:
# [{'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'FsmGJxppnlY',
#   'Video_Title': 'What method you are going to choose? I Computer Science Degrees I Admissions Open I 2024 I Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/FsmGJxppnlY/default.jpg',
#   'Description': 'Fill this link to know the details: https://forms.gle/iXQuWvDSnxfxfdCT8\n\nWhy should you get a degree from FACE Prep Campus? \n\n1.  Learn Computer Science related degrees integrated with Artificial Intelligence, Machine Learning & Full Stack Development with the guidance of industry expertise mentors in the classroom atmosphere of IT workplace.                                     \n\n2. Gain skills through practical-based learning.                                                                                                                                                                              \n\n3. Get a Course completion certificate on in-demand technology like Artificial Intelligence, Machine Learning & Full Stack Development by FACE Prep Campus.\n\n4. Get a Graduation certificate from the college-affiliated university. \n\n5. Paid internship at the end of the second year.\n\n6. Assured placements with a salary package of 3 to 10 Lakhs per annum. \n\n#admissionsopen2024_25 #admissionsopen #topcollegeinindia #topcollegeincoimbatore #bestcolleges #tamilnadu #educationalvideo #practicallearning #placement #internship #highsalaryjob',
#   'Published_Date': '2024-05-24T07:57:45Z',
#   'Duration': 'PT1M1S',
#   'Views_Count': '4',
#   'Likes_Count': '2',
#   'Comments_Count': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'dA4XM5u-6Oc',
#   'Video_Title': '4 Things to remember before 12th public exam results | May 6 | Tamil | FACE Prep Campus',
#   'Thumbnail': 'https://i.ytimg.com/vi/dA4XM5u-6Oc/default.jpg',
#   'Description': 'About to get your 12th-grade results?\nTake a breath and check out our quick YouTube short for 4 essential reminders to keep you grounded and focused.\nSTAY STRONG!',
#   'Published_Date': '2024-05-04T04:34:46Z',
#   'Duration': 'PT1M',
#   'Views_Count': '702',
#   'Likes_Count': '34',
#   'Comments_Count': '1',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'G9OEsPZGVWs',
#   'Video_Title': 'Can a Commerce/Pure Science group students study Computer Science related degrees? I Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/G9OEsPZGVWs/default.jpg',
#   'Description': 'Curious if students from commerce or pure science backgrounds can pursue computer science degrees? This video explores the possibilities and challenges for those interested in crossing over into the world of computer science. Join us as we discuss pathways, challenges, and opportunities for students looking to blend their interests. Watch now to learn how you can bridge the gap between different fields and thrive in computer science!',
#   'Published_Date': '2024-04-15T04:45:58Z',
#   'Duration': 'PT1M12S',
#   'Views_Count': '215',
#   'Likes_Count': '4',
#   'Comments_Count': '14',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': '6tGfa9aepz0',
#   'Video_Title': 'TNAU | Agriculture | Counselling | Cutoff Calculation | 2024 | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/6tGfa9aepz0/default.jpg',
#   'Description': 'Get to know how to calculate the cutoff for TNAU conselling by watching this video!',
#   'Published_Date': '2024-04-09T08:41:12Z',
#   'Duration': 'PT55S',
#   'Views_Count': '3177',
#   'Likes_Count': '129',
#   'Comments_Count': '2',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'Il-Wd_88fZE',
#   'Video_Title': '12th Biology | Public exam | Study Plan | FACE Prep Campus | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/Il-Wd_88fZE/default.jpg',
#   'Description': "📚Last 2 days study plan for 12th public Biology exam!\n\nFeeling nervous for your exam? Don't worry! This video is here to help you get ready in the last 2 days. We've got easy tips on what to study. \n\n👍 Watch this video to prepare well and walk into your exam with confidence. Like and share if you find it helpful, and don't forget to subscribe for more simple study tips. All The Best!",
#   'Published_Date': '2024-03-19T08:31:11Z',
#   'Duration': 'PT1M',
#   'Views_Count': '2788',
#   'Likes_Count': '82',
#   'Comments_Count': '1',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'A4-WwASNAnE',
#   'Video_Title': '12th Business Maths & Statistics | Public exam | Study Plan | FACE Prep Campus | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/A4-WwASNAnE/default.jpg',
#   'Description': "📚Last 2 days study plan for 12th public Business Maths & Statistics exam!\n\nFeeling nervous for your exam? Don't worry! This video is here to help you get ready in the last 2 days. We've got easy tips on what to study. \n\n👍 Watch this video to prepare well and walk into your exam with confidence. Like and share if you find it helpful, and don't forget to subscribe for more simple study tips. All The Best!",
#   'Published_Date': '2024-03-19T08:05:48Z',
#   'Duration': 'PT40S',
#   'Views_Count': '883',
#   'Likes_Count': '47',
#   'Comments_Count': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'TDYtHZAaxHw',
#   'Video_Title': 'FACE TO FACE Prep Campus Conversation | Mentors | Parents | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/TDYtHZAaxHw/default.jpg',
#   'Description': 'FACE to FACE Prep Campus Conversations, where we discuss the great progress of our students with their parents, and here is what occurred in FACE TO FACE.',
#   'Published_Date': '2024-03-17T14:59:27Z',
#   'Duration': 'PT1M',
#   'Views_Count': '1032',
#   'Likes_Count': '33',
#   'Comments_Count': '2',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'MusbnHeGeP8',
#   'Video_Title': 'FACE TO FACE Prep Campus Conversation | Mentors | Parents | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/MusbnHeGeP8/default.jpg',
#   'Description': 'FACE to FACE Prep Campus Conversations, where we discuss the great progress of our students with their parents, and here is what occurred in FACE TO FACE.',
#   'Published_Date': '2024-03-16T10:25:12Z',
#   'Duration': 'PT1M',
#   'Views_Count': '737',
#   'Likes_Count': '17',
#   'Comments_Count': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'UEa9eeClLFI',
#   'Video_Title': '12th Maths | Public exam | Study Plan | FACE Prep Campus | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/UEa9eeClLFI/default.jpg',
#   'Description': "📚Last 3 days study plan for 12th public Mathematics exam!\n\nFeeling nervous for your exam? Don't worry! This video is here to help you get ready in the last 3 days. We've got easy tips on what to study. \n\n👍 Watch this video to prepare well and walk into your exam with confidence. Like and share if you find it helpful, and don't forget to subscribe for more simple study tips. All The Best!",
#   'Published_Date': '2024-03-15T07:45:01Z',
#   'Duration': 'PT1M',
#   'Views_Count': '1413',
#   'Likes_Count': '74',
#   'Comments_Count': '3',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'TKfiti3_vyY',
#   'Video_Title': 'FACE TO FACE Prep Campus Conversations | Mentors | Parents | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/TKfiti3_vyY/default.jpg',
#   'Description': "FACE to FACE Prep Campus Conversations, our students' recent achievements are increasing day by day! And we thought of showing this great progress with their parents, and here is what occurred in FACE TO FACE. \n\nThese kinds of conversations are not in normal colleges, even if they have, they'll take that into a meeting to talk about students' failures on exams. But here at FACE Prep Campus, we make sure every parent is constantly updated on their child's progress!\n\nTo know about FACE Prep Campus, do WhatsApp/Call: 7904318695",
#   'Published_Date': '2024-03-13T10:13:07Z',
#   'Duration': 'PT1M',
#   'Views_Count': '827',
#   'Likes_Count': '26',
#   'Comments_Count': '1',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'PwOrzH4g2Dg',
#   'Video_Title': '12th Physics | Public Exam | 3 days study plan | FACE Prep Campus | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/PwOrzH4g2Dg/default.jpg',
#   'Description': "📚Last 3 days study plan for 12th public Physics exam!\n\nFeeling nervous for your Physics exam? Don't worry! This video is here to help you get ready in the last 2 days. We've got easy tips on what to study. \n\n👍 Watch this video to prepare well and walk into your exam with confidence. Like and share if you find it helpful, and don't forget to subscribe for more simple study tips. All The Best!",
#   'Published_Date': '2024-03-12T08:38:48Z',
#   'Duration': 'PT50S',
#   'Views_Count': '971',
#   'Likes_Count': '45',
#   'Comments_Count': '3',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': '0ETaOu7yu-Q',
#   'Video_Title': 'FACE TO FACE Prep Campus Conversation | Mentors | Parents | Tamil | Part 2',
#   'Thumbnail': 'https://i.ytimg.com/vi/0ETaOu7yu-Q/default.jpg',
#   'Description': "FACE to FACE Prep Campus Conversations, our students' recent achievements are increasing day by day! And we thought of showing this great progress with their parents, and here is what occurred in FACE TO FACE. \n\nThese kinds of conversations are not in normal colleges, even if they have, they'll take that into a meeting to talk about students' failures on exams. But here at FACE Prep Campus, we make sure every parent is constantly updated on their child's progress!\n\nTo know about FACE Prep Campus, do WhatsApp/Call: 7904318695",
#   'Published_Date': '2024-03-12T07:20:18Z',
#   'Duration': 'PT40S',
#   'Views_Count': '736',
#   'Likes_Count': '33',
#   'Comments_Count': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': '7gNXXeDUhe8',
#   'Video_Title': 'FACE TO FACE Prep Campus Conversations | Parents | Mentors | Tamil | Part 1',
#   'Thumbnail': 'https://i.ytimg.com/vi/7gNXXeDUhe8/default.jpg',
#   'Description': "FACE to FACE Prep Campus Conversations, our students' recent achievements are increasing day by day! And we thought of showing this great progress with their parents, and here is what occurred in FACE TO FACE. \n\nThese kinds of conversations are not in normal colleges, even if they have, they'll take that into a meeting to talk about students' failures on exams. But here at FACE Prep Campus, we make sure every parent is constantly updated on their child's progress!",
#   'Published_Date': '2024-03-11T09:45:59Z',
#   'Duration': 'PT1M',
#   'Views_Count': '536',
#   'Likes_Count': '10',
#   'Comments_Count': '1',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'gckt7y6TqYo',
#   'Video_Title': '12th Chemistry | Public Exam | 2 days study plan | FACE Prep Campus | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/gckt7y6TqYo/default.jpg',
#   'Description': "📚Last 2 days study plan for 12th public Chemistry exam!\n\nFeeling nervous for your Chemistry exam? Don't worry! This video is here to help you get ready in the last 2 days. We've got easy tips on what to study. \n\n👍 Watch this video to prepare well and walk into your exam with confidence. Like and share if you find it helpful, and don't forget to subscribe for more simple study tips. Good luck! \n\n#ChemistryExam #StudyTips #LastMinuteStudy #SimpleStudyPla",
#   'Published_Date': '2024-03-08T12:34:48Z',
#   'Duration': 'PT48S',
#   'Views_Count': '1473',
#   'Likes_Count': '59',
#   'Comments_Count': '1',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'apekYaY2ZGE',
#   'Video_Title': 'EMI Option | Computer Science | Degree | FACE Prep Campus | Admissions Open | 2024 | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/apekYaY2ZGE/default.jpg',
#   'Description': 'EMI Option-ஐ பயன்படுத்தி, FACE Prep Campus-ன் கல்லூரிகளில், 100% உறுதியளிக்கப்பட்ட வேலைவாய்ப்பு தரக்கூடிய Computer Science related degree-ஐ படிக்க வேண்டும் எனில், \n\nCall: 7904318695\nWhatsApp: https://bit.ly/49Xeyry\n\nதமிழகத்தின் best job-oriented computer science degree program-ஐ வழங்கும் FACE Prep Campus-ன் சிறப்பம்சங்கள்,\n\n1. Practical அடிப்படையிலான Learning.\n\n2.  தொழில்நுட்ப Skills (Artificial Intelligence, Machine Learning, Data Science மற்றும் Full Stack Development) degree உடன் வழங்கப்படும்.\n\n3. Graduation Certificate from College - Affiliated University.\n\n5. Industry Expertise Mentors \n\n6. இரண்டாம் ஆண்டு முடிவில் paid internship வாய்ப்புகள்.\n\n7. மாதம் 50,000 வரை சம்பளத்துடன் உறுதியளிக்கப்பட்ட வேலை வாய்ப்புகள்.',
#   'Published_Date': '2024-03-06T09:20:18Z',
#   'Duration': 'PT1M17S',
#   'Views_Count': '417',
#   'Likes_Count': '10',
#   'Comments_Count': '6',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'qUJTkohDOxc',
#   'Video_Title': 'The Best College in Thoothukudi | Artificial Intelligence Course | Placement Assured',
#   'Thumbnail': 'https://i.ytimg.com/vi/qUJTkohDOxc/default.jpg',
#   'Description': 'FACE Prep Campus பற்றி மேலும் தெரிந்து கொள்ள, கீழே உள்ள link-ஐ click செய்யவும்: https://bit.ly/3Tms5Ef \n\nApplication Form-ஐ பெற, கீழே உள்ள link-ஐ click செய்யவும்:  https://pages.razorpay.com/pl_NAcDtbp7HpOxwA/view\n\n(OR) CONTACT📞 - 79043 18695\n\nதமிழகத்தின் best job-oriented computer science degree program-ஐ வழங்கும் FACE Prep Campus-ன் சிறப்பம்சங்கள்,\n\n1. Practical அடிப்படையிலான Learning.\n\n2.  தொழில்நுட்ப Skills (Artificial Intelligence, Machine Learning, Data Science மற்றும் Full Stack Development) degree உடன் வழங்கப்படும்.\n\n3. Graduation Certificate from College - Affiliated University.\n\n5. Industry Expertise Mentors \n\n6. இரண்டாம் ஆண்டு முடிவில் paid internship வாய்ப்புகள்.\n\n7. மாதம் 50,000 வரை சம்பளத்துடன் உறுதியளிக்கப்பட்ட வேலை வாய்ப்புகள்.\n\nLOCATION:\nKamaraj College\n482, Tiruchendur Road - 628003',
#   'Published_Date': '2024-02-15T11:30:32Z',
#   'Duration': 'PT2M6S',
#   'Views_Count': '385',
#   'Likes_Count': '17',
#   'Comments_Count': '10',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'CP2Me9AUPA0',
#   'Video_Title': 'The Best College in Chennai | Artificial Intelligence Course | Placement Assured | FACE Prep Campus',
#   'Thumbnail': 'https://i.ytimg.com/vi/CP2Me9AUPA0/default.jpg',
#   'Description': 'FACE Prep Campus பற்றி மேலும் தெரிந்து கொள்ள, கீழே உள்ள link-ஐ click செய்யவும்: https://bit.ly/3Tms5Ef \n\nApplication Form-ஐ பெற, கீழே உள்ள link-ஐ click செய்யவும்:  https://pages.razorpay.com/pl_NAcDtbp7HpOxwA/view\n\n(OR) CONTACT📞 - 79043 18695\n\nதமிழகத்தின் best job-oriented computer science degree program-ஐ வழங்கும் FACE Prep Campus-ன் சிறப்பம்சங்கள்,\n\n1. Practical அடிப்படையிலான Learning.\n\n2.  தொழில்நுட்ப Skills (Artificial Intelligence, Machine Learning, Data Science மற்றும் Full Stack Development) degree உடன் வழங்கப்படும்.\n\n3. Graduation Certificate from College - Affiliated University.\n\n5. Industry Expertise Mentors \n\n6. இரண்டாம் ஆண்டு முடிவில் paid internship வாய்ப்புகள்.\n\n7. மாதம் 50,000 வரை சம்பளத்துடன் உறுதியளிக்கப்பட்ட வேலை வாய்ப்புகள்.\n\nLOCATION:\nPrince Shri Balaji Arts and Science College\nMedavakkam - Mambakkam Road,\nPonmar-600127',
#   'Published_Date': '2024-02-15T10:30:08Z',
#   'Duration': 'PT2M5S',
#   'Views_Count': '518',
#   'Likes_Count': '16',
#   'Comments_Count': '14',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': '78WxtTkcIgI',
#   'Video_Title': 'The Best College in Tiruppur | BSc IT degree | Placement Assured | FACE Prep Campus',
#   'Thumbnail': 'https://i.ytimg.com/vi/78WxtTkcIgI/default.jpg',
#   'Description': 'FACE Prep Campus பற்றி மேலும் தெரிந்து கொள்ள, கீழே உள்ள link-ஐ click செய்யவும்: https://bit.ly/3Tms5Ef \n\nApplication Form-ஐ பெற, கீழே உள்ள link-ஐ click செய்யவும்:  https://pages.razorpay.com/pl_NAcDtbp...\n\n(OR) CONTACT📞 - 79043 18695\n\nதமிழகத்தின் best job-oriented computer science degree program-ஐ வழங்கும் FACE Prep Campus-ன் சிறப்பம்சங்கள்,\n\n1. Practical அடிப்படையிலான Learning.\n\n2.  தொழில்நுட்ப Skills (Artificial Intelligence, Machine Learning, Data Science மற்றும் Full Stack Development) degree உடன் வழங்கப்படும்.\n\n3. Graduation Certificate from College - Affiliated University.\n\n5. Industry Expertise Mentors \n\n6. இரண்டாம் ஆண்டு முடிவில் paid internship வாய்ப்புகள்.\n\n7. மாதம் 50,000 வரை சம்பளத்துடன் உறுதியளிக்கப்பட்ட வேலை வாய்ப்புகள்.\n\nLOCATION:\nTerf’s Academy College of Arts and Science,\nKovilpalayam Pudur, Avinashipalayam Post,\nTirupur, Tamil Nadu–638 660',
#   'Published_Date': '2024-02-15T10:11:18Z',
#   'Duration': 'PT2M12S',
#   'Views_Count': '213',
#   'Likes_Count': '8',
#   'Comments_Count': '6',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'Mj4qBRthUZI',
#   'Video_Title': 'The Best College in Dharapuram | Tiruppur | BSc IT degree | Placement Assured | FACE Prep Campus',
#   'Thumbnail': 'https://i.ytimg.com/vi/Mj4qBRthUZI/default.jpg',
#   'Description': 'FACE Prep Campus பற்றி மேலும் தெரிந்து கொள்ள, கீழே உள்ள link-ஐ click செய்யவும்: https://bit.ly/3Tms5Ef \n\nApplication Form-ஐ பெற, கீழே உள்ள link-ஐ click செய்யவும்:  https://pages.razorpay.com/pl_NAcDtbp...\n\n(OR) CONTACT📞 - 79043 18695\n\nதமிழகத்தின் best job-oriented computer science degree program-ஐ வழங்கும் FACE Prep Campus-ன் சிறப்பம்சங்கள்,\n\n1. Practical அடிப்படையிலான Learning.\n\n2.  தொழில்நுட்ப Skills (Artificial Intelligence, Machine Learning, Data Science மற்றும் Full Stack Development) degree உடன் வழங்கப்படும்.\n\n3. Graduation Certificate from College - Affiliated University.\n\n5. Industry Expertise Mentors \n\n6. இரண்டாம் ஆண்டு முடிவில் paid internship வாய்ப்புகள்.\n\n7. மாதம் 50,000 வரை சம்பளத்துடன் உறுதியளிக்கப்பட்ட வேலை வாய்ப்புகள்.\n\nLOCATION:\nMaharani Arts & Science College\nNanjiyampalayam, Tamil Nadu 638657',
#   'Published_Date': '2024-02-15T10:02:44Z',
#   'Duration': 'PT2M3S',
#   'Views_Count': '97',
#   'Likes_Count': '3',
#   'Comments_Count': '1',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': '8vjRNzQwdy8',
#   'Video_Title': 'The Best College in Erode | Artificial Intelligence Course | Placement Assured | FACE Prep Campus',
#   'Thumbnail': 'https://i.ytimg.com/vi/8vjRNzQwdy8/default.jpg',
#   'Description': 'FACE Prep Campus பற்றி மேலும் தெரிந்து கொள்ள, கீழே உள்ள link-ஐ click செய்யவும்: https://bit.ly/3Tms5Ef \n\nApplication Form-ஐ பெற, கீழே உள்ள link-ஐ click செய்யவும்:  https://pages.razorpay.com/pl_NAcDtbp7HpOxwA/view\n\n(OR) CONTACT📞 - 79043 18695\n\nதமிழகத்தின் best job-oriented computer science degree program-ஐ வழங்கும் FACE Prep Campus-ன் சிறப்பம்சங்கள்,\n\n1. Practical அடிப்படையிலான Learning.\n\n2.  தொழில்நுட்ப Skills (Artificial Intelligence, Machine Learning, Data Science மற்றும் Full Stack Development) degree உடன் வழங்கப்படும்.\n\n3. Graduation Certificate from College - Affiliated University.\n\n5. Industry Expertise Mentors \n\n6. இரண்டாம் ஆண்டு முடிவில் paid internship வாய்ப்புகள்.\n\n7. மாதம் 50,000 வரை சம்பளத்துடன் உறுதியளிக்கப்பட்ட வேலை வாய்ப்புகள்.\n\nLOCATION:\nBharathidasan College of Arts and Science\nChithode to kavindapadi Road, \nEllispettai, \nPallapalayam \n(PO)-638116',
#   'Published_Date': '2024-02-15T10:00:09Z',
#   'Duration': 'PT2M2S',
#   'Views_Count': '233',
#   'Likes_Count': '9',
#   'Comments_Count': '8',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'B06aRs1rvKg',
#   'Video_Title': 'The Best College in Coimbatore | Artificial Intelligence Course | Placement Assured | FP Campus',
#   'Thumbnail': 'https://i.ytimg.com/vi/B06aRs1rvKg/default.jpg',
#   'Description': 'FACE Prep Campus பற்றி மேலும் தெரிந்து கொள்ள, கீழே உள்ள link-ஐ click செய்யவும்: https://bit.ly/3Tms5Ef \n\nApplication Form-ஐ பெற, கீழே உள்ள link-ஐ click செய்யவும்:  https://pages.razorpay.com/pl_NAcDtbp7HpOxwA/view\n\n(OR) CONTACT📞 - 79043 18695\n\nதமிழகத்தின் best job-oriented computer science degree program-ஐ வழங்கும் FACE Prep Campus-ன் சிறப்பம்சங்கள்,\n\n1. Practical அடிப்படையிலான Learning.\n\n2.  தொழில்நுட்ப Skills (Artificial Intelligence, Machine Learning, Data Science மற்றும் Full Stack Development) degree உடன் வழங்கப்படும்.\n\n3. Graduation Certificate from College - Affiliated University.\n\n5. Industry Expertise Mentors \n\n6. இரண்டாம் ஆண்டு முடிவில் paid internship வாய்ப்புகள்.\n\n7. மாதம் 50,000 வரை சம்பளத்துடன் உறுதியளிக்கப்பட்ட வேலை வாய்ப்புகள்.\n\nLOCATION:\nSAN International College of Arts & Science\nPudhupathy Road, \nTaluk, Mavuthampathi, \nMadukkarai-641105',
#   'Published_Date': '2024-02-15T09:36:00Z',
#   'Duration': 'PT2M3S',
#   'Views_Count': '606',
#   'Likes_Count': '21',
#   'Comments_Count': '6',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'XHaEuPzOsig',
#   'Video_Title': 'The Best College in Karur | Artificial Intelligence Course | Placement Assured | FACE Prep Campus',
#   'Thumbnail': 'https://i.ytimg.com/vi/XHaEuPzOsig/default.jpg',
#   'Description': 'FACE Prep Campus பற்றி மேலும் தெரிந்து கொள்ள, கீழே உள்ள link-ஐ click செய்யவும்: https://bit.ly/3Tms5Ef \n\nApplication Form-ஐ பெற, கீழே உள்ள link-ஐ click செய்யவும்:  https://pages.razorpay.com/pl_NAcDtbp7HpOxwA/view\n\n(OR) CONTACT📞 - 79043 18695\n\nதமிழகத்தின் best job-oriented computer science degree program-ஐ வழங்கும் FACE Prep Campus-ன் சிறப்பம்சங்கள்,\n\n1. Practical அடிப்படையிலான Learning.\n\n2.  தொழில்நுட்ப Skills (Artificial Intelligence, Machine Learning, Data Science மற்றும் Full Stack Development) degree உடன் வழங்கப்படும்.\n\n3. Graduation Certificate from College - Affiliated University.\n\n5. Industry Expertise Mentors \n\n6. இரண்டாம் ஆண்டு முடிவில் paid internship வாய்ப்புகள்.\n\n7. மாதம் 50,000 வரை சம்பளத்துடன் உறுதியளிக்கப்பட்ட வேலை வாய்ப்புகள்.\n\nFACE Prep Campus பற்றி மேலும் தெரிந்து கொள்ள, கீழே உள்ள link-ஐ click செய்யவும்: https://bit.ly/3Tms5Ef \n\nApplication Form-ஐ பெற, கீழே உள்ள link-ஐ click செய்யவும்:  https://pages.razorpay.com/pl_NAcDtbp7HpOxwA/view\n\nLOCATION:\nThirumalainathanpatti,\nVelliyanai-639118',
#   'Published_Date': '2024-02-15T05:30:04Z',
#   'Duration': 'PT1M59S',
#   'Views_Count': '107',
#   'Likes_Count': '5',
#   'Comments_Count': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'Hi_CwdFlpKg',
#   'Video_Title': 'The Best College in Madurai | Artificial Intelligence Course | Placement Assured | FACE Prep Campus',
#   'Thumbnail': 'https://i.ytimg.com/vi/Hi_CwdFlpKg/default.jpg',
#   'Description': 'FACE Prep Campus பற்றி மேலும் தெரிந்து கொள்ள, கீழே உள்ள link-ஐ click செய்யவும்: https://bit.ly/3Tms5Ef \n\nApplication Form-ஐ பெற, கீழே உள்ள link-ஐ click செய்யவும்:  https://pages.razorpay.com/pl_NAcDtbp7HpOxwA/view\n\n(OR) CONTACT📞 - 79043 18695\n\nதமிழகத்தின் best job-oriented computer science degree program-ஐ வழங்கும் FACE Prep Campus-ன் சிறப்பம்சங்கள்,\n\n1. Practical அடிப்படையிலான Learning.\n\n2.  தொழில்நுட்ப Skills (Artificial Intelligence, Machine Learning, Data Science மற்றும் Full Stack Development) degree உடன் வழங்கப்படும்.\n\n3. Graduation Certificate from College - Affiliated University.\n\n5. Industry Expertise Mentors \n\n6. இரண்டாம் ஆண்டு முடிவில் paid internship வாய்ப்புகள்.\n\n7. மாதம் 50,000 வரை சம்பளத்துடன் உறுதியளிக்கப்பட்ட வேலை வாய்ப்புகள்.\n\nFACE Prep Campus பற்றி மேலும் தெரிந்து கொள்ள, கீழே உள்ள link-ஐ click செய்யவும்: https://bit.ly/3Tms5Ef \n\nApplication Form-ஐ பெற, கீழே உள்ள link-ஐ click செய்யவும்:  https://pages.razorpay.com/pl_NAcDtbp7HpOxwA/view\n\nLOCATION:\nS.No.32/1, Valayankulam Village,\nNear Airport,\nFour way Track-625022',
#   'Published_Date': '2024-02-14T11:30:09Z',
#   'Duration': 'PT2M4S',
#   'Views_Count': '364',
#   'Likes_Count': '11',
#   'Comments_Count': '6',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'x7Ub1LkrKVE',
#   'Video_Title': 'The Best College in Trichy | Nehru Memorial College | Artificial Intelligence Course | FP Campus',
#   'Thumbnail': 'https://i.ytimg.com/vi/x7Ub1LkrKVE/default.jpg',
#   'Description': 'FACE Prep Campus பற்றி மேலும் தெரிந்து கொள்ள, கீழே உள்ள link-ஐ click செய்யவும்: https://bit.ly/3Tms5Ef \n\nApplication Form-ஐ பெற, கீழே உள்ள link-ஐ click செய்யவும்:  https://pages.razorpay.com/pl_NAcDtbp7HpOxwA/view\n\n(OR) CONTACT📞 - 79043 18695\n\nதமிழகத்தின் best job-oriented computer science degree program-ஐ வழங்கும் FACE Prep Campus-ன் சிறப்பம்சங்கள்,\n\n1. Practical அடிப்படையிலான Learning.\n\n2.  தொழில்நுட்ப Skills (Artificial Intelligence, Machine Learning, Data Science மற்றும் Full Stack Development) degree உடன் வழங்கப்படும்.\n\n3. Graduation Certificate from College - Affiliated University.\n\n5. Industry Expertise Mentors \n\n6. இரண்டாம் ஆண்டு முடிவில் paid internship வாய்ப்புகள்.\n\n7. மாதம் 50,000 வரை சம்பளத்துடன் உறுதியளிக்கப்பட்ட வேலை வாய்ப்புகள்.\n\nLOCATION:\nPuthanampatti-621007',
#   'Published_Date': '2024-02-14T05:30:14Z',
#   'Duration': 'PT2M1S',
#   'Views_Count': '237',
#   'Likes_Count': '14',
#   'Comments_Count': '7',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': '2LnOlUvkZ9M',
#   'Video_Title': 'The Best Colleges in Salem | Artificial Intelligence Course | Placement Assured | FACE Prep Campus',
#   'Thumbnail': 'https://i.ytimg.com/vi/2LnOlUvkZ9M/default.jpg',
#   'Description': 'FACE Prep Campus பற்றி மேலும் தெரிந்து கொள்ள, கீழே உள்ள link-ஐ click செய்யவும்: https://bit.ly/3Tms5Ef \n\n(OR) CONTACT📞 - 79043 18695\n\nApplication Form-ஐ பெற, கீழே உள்ள link-ஐ click செய்யவும்:  https://pages.razorpay.com/pl_NAcDtbp7HpOxwA/view\n\nதமிழகத்தின் best job-oriented computer science degree program-ஐ வழங்கும் FACE Prep Campus-ன் சிறப்பம்சங்கள்,\n\n1. Practical அடிப்படையிலான Learning.\n\n2.  தொழில்நுட்ப Skills (Artificial Intelligence, Machine Learning, Data Science மற்றும் Full Stack Development) degree உடன் வழங்கப்படும்.\n\n3. Graduation Certificate from College - Affiliated University.\n\n5. Industry Expertise Mentors \n\n6. இரண்டாம் ஆண்டு முடிவில் paid internship வாய்ப்புகள்.\n\n7. மாதம் 50,000 வரை சம்பளத்துடன் உறுதியளிக்கப்பட்ட வேலை வாய்ப்புகள்.\n\nLOCATION:\n1. Jairam Arts and Science College - Chinna Tirupathi - 636 007\n2. Vysya College - Ayodhyapattanam (P.O), Ramakrishnapuram, Dasanaickenpatti- 636 103',
#   'Published_Date': '2024-02-13T09:02:35Z',
#   'Duration': 'PT2M11S',
#   'Views_Count': '250',
#   'Likes_Count': '6',
#   'Comments_Count': '15',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'y6LW8wtGIgM',
#   'Video_Title': '12th Physics Important 5 Mark Questions | Public Questions | Frequently Asked | 12th Students',
#   'Thumbnail': 'https://i.ytimg.com/vi/y6LW8wtGIgM/default.jpg',
#   'Description': "📚Most Asked Public 5 Mark Questions in 12th Physics!\n\n📊📖 If you're a Tamil Nadu student gearing up for your exams, this video is your ultimate guide to nailing those critical 5-mark questions. 🎯 From essential concepts to insightful explanations, we've got you covered. Boost your confidence and ace your exams with FACE Prep Campus! 🚀📝\n\n#12thphysics #exampreparation  #tamilnadustudents  #topquestions  #faceprepcampus #educationmatters #physics #physicsquestions",
#   'Published_Date': '2024-01-19T12:44:03Z',
#   'Duration': 'PT1M',
#   'Views_Count': '2283',
#   'Likes_Count': '205',
#   'Comments_Count': '16',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': '877t1yyKwkI',
#   'Video_Title': '12th Computer Science Important 5 Mark Questions | Public Questions | 12th Students |',
#   'Thumbnail': 'https://i.ytimg.com/vi/877t1yyKwkI/default.jpg',
#   'Description': "📚Most Asked Public 5 Mark Questions in 12th Computer Science!\n\n📊📖 If you're a Tamil Nadu student gearing up for your exams, this video is your ultimate guide to nailing those critical 5-mark questions. 🎯 From essential concepts to insightful explanations, we've got you covered. Boost your confidence and ace your exams with FACE Prep Campus! 🚀📝\n\n#12thcomputerscience #exampreparation  #tamilnadustudents  #topquestions  #faceprepcampus #educationmatters #computerscience  #computersciencequestions",
#   'Published_Date': '2024-01-19T12:31:11Z',
#   'Duration': 'PT59S',
#   'Views_Count': '2849',
#   'Likes_Count': '254',
#   'Comments_Count': '7',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'qFAaBX0OXko',
#   'Video_Title': '12th Economics Public 5 mark Questions | 2024 | 12th Students | Public Exam | Frequently asked',
#   'Thumbnail': 'https://i.ytimg.com/vi/qFAaBX0OXko/default.jpg',
#   'Description': "📚Most Asked Public 5 Mark Questions in 12th Economics!\n\n📊📖 If you're a Tamil Nadu student gearing up for your exams, this video is your ultimate guide to nailing those critical 5-mark questions. 🎯 From essential concepts to insightful explanations, we've got you covered. Boost your confidence and ace your exams with FACE Prep Campus! 🚀📝\n\n#12theconomics #exampreparation  #tamilnadustudents  #topquestions  #faceprepcampus #educationmatters #economics  #economicsquestions",
#   'Published_Date': '2024-01-18T14:30:17Z',
#   'Duration': 'PT1M',
#   'Views_Count': '1009',
#   'Likes_Count': '105',
#   'Comments_Count': '13',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'AnORSQMvbco',
#   'Video_Title': '12th Chemistry Public 5 Mark Questions | Board Exam | 12th Students | Frequently asked Questions',
#   'Thumbnail': 'https://i.ytimg.com/vi/AnORSQMvbco/default.jpg',
#   'Description': "📚Most Asked Public 5 Mark Questions in 12th Chemistry!\n\n📊📖 If you're a Tamil Nadu student gearing up for your exams, this video is your ultimate guide to nailing those critical 5-mark questions. 🎯 From essential concepts to insightful explanations, we've got you covered. Boost your confidence and ace your exams with FACE Prep Campus! 🚀📝\n\n#12thchemistry #exampreparation  #tamilnadustudents  #topquestions  #faceprepcampus #educationmatters #chemistry #chemistryquestions",
#   'Published_Date': '2024-01-18T12:15:46Z',
#   'Duration': 'PT59S',
#   'Views_Count': '926',
#   'Likes_Count': '120',
#   'Comments_Count': '10',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'WS-5DtAqymM',
#   'Video_Title': '12th Commerce Public 5 Marks | Frequently asked questions | 12th Public Exam',
#   'Thumbnail': 'https://i.ytimg.com/vi/WS-5DtAqymM/default.jpg',
#   'Description': "📚Most Asked Public 5 Mark Questions in 12th Commerce!\n\n📊📖 If you're a Tamil Nadu student gearing up for your exams, this video is your ultimate guide to nailing those critical 5-mark questions. 🎯 From essential concepts to insightful explanations, we've got you covered. Boost your confidence and ace your exams with FACE Prep Campus! 🚀📝\n\n#12thcommerce #exampreparation  #tamilnadustudents  #topquestions  #faceprepcampus #educationmatters #commerce  #commercequestions",
#   'Published_Date': '2024-01-17T15:06:34Z',
#   'Duration': 'PT1M',
#   'Views_Count': '1761',
#   'Likes_Count': '205',
#   'Comments_Count': '12',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'nCYtXDLkBBc',
#   'Video_Title': '12th Economics Important 3 Mark Questions | Public Questions | 12th Students | Most Asked Questions',
#   'Thumbnail': 'https://i.ytimg.com/vi/nCYtXDLkBBc/default.jpg',
#   'Description': "📚Most Asked Public 3 Mark Questions in 12th Economics! \n\n📊📖 If you're a Tamil Nadu student gearing up for your exams, this video is your ultimate guide to nailing those critical 3-mark questions. 🎯 From essential concepts to insightful explanations, we've got you covered. Boost your confidence and ace your exams with FACE Prep Campus! 🚀📝\n\n#12theconomics #exampreparation  #tamilnadustudents  #topquestions  #faceprepcampus #educationmatters #economics #economicsquestions",
#   'Published_Date': '2024-01-17T05:59:13Z',
#   'Duration': 'PT1M',
#   'Views_Count': '780',
#   'Likes_Count': '65',
#   'Comments_Count': '3',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'anQAMsAXVHs',
#   'Video_Title': '12th Physics Important 3 Marks | Board Exams | 12th Students | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/anQAMsAXVHs/default.jpg',
#   'Description': 'தமிழகத்தின் best job-oriented computer science degree program-ஐ வழங்கும் FACE Prep Campus-ன் சிறப்பம்சங்கள்,\n\n1. Practical அடிப்படையிலான Learning.\n\n2.  தொழில்நுட்ப Skills (Artificial Intelligence, Machine Learning, Data Science மற்றும் Full Stack Development) degree உடன் வழங்கப்படும்.\n\n3. Graduation Certificate from College - Affiliated University.\n\n5. Industry Expertise Mentors \n\n6. இரண்டாம் ஆண்டு முடிவில் paid internship வாய்ப்புகள்.\n\n7. மாதம் 50,000 வரை சம்பளத்துடன் உறுதியளிக்கப்பட்ட வேலை வாய்ப்புகள்.\n\nFACE Prep Campus பற்றி மேலும் தெரிந்து கொள்ள, கீழே உள்ள link-ஐ click செய்யவும்: https://bit.ly/3Tms5Ef \n\nApplication Form-ஐ பெற, கீழே உள்ள link-ஐ click செய்யவும்:  https://pages.razorpay.com/pl_NAcDtbp7HpOxwA/view',
#   'Published_Date': '2024-01-15T15:30:00Z',
#   'Duration': 'PT59S',
#   'Views_Count': '761',
#   'Likes_Count': '71',
#   'Comments_Count': '5',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'zPdnlEvWKD0',
#   'Video_Title': '12th Commerce Important 3 Marks | Board Exams | Students | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/zPdnlEvWKD0/default.jpg',
#   'Description': 'தமிழகத்தின் best job-oriented computer science degree program-ஐ வழங்கும் FACE Prep Campus-ன் சிறப்பம்சங்கள்,\n\n1. Practical அடிப்படையிலான Learning.\n\n2.  தொழில்நுட்ப Skills (Artificial Intelligence, Machine Learning, Data Science மற்றும் Full Stack Development) degree உடன் வழங்கப்படும்.\n\n3. Graduation Certificate from College - Affiliated University.\n\n5. Industry Expertise Mentors \n\n6. இரண்டாம் ஆண்டு முடிவில் paid internship வாய்ப்புகள்.\n\n7. மாதம் 50,000 வரை சம்பளத்துடன் உறுதியளிக்கப்பட்ட வேலை வாய்ப்புகள்.\n\nFACE Prep Campus பற்றி மேலும் தெரிந்து கொள்ள, கீழே உள்ள link-ஐ click செய்யவும்: https://bit.ly/3Tms5Ef \n\nApplication Form-ஐ பெற, கீழே உள்ள link-ஐ click செய்யவும்:  https://pages.razorpay.com/pl_NAcDtbp7HpOxwA/view',
#   'Published_Date': '2024-01-15T14:27:16Z',
#   'Duration': 'PT56S',
#   'Views_Count': '388',
#   'Likes_Count': '42',
#   'Comments_Count': '2',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': '2Y6PRWVk1Ng',
#   'Video_Title': 'What next AFTER 12th? | Webinar | FACE Prep Campus | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/2Y6PRWVk1Ng/default.jpg',
#   'Description': 'தமிழகத்தின் best job-oriented computer science degree program-ஐ வழங்கும் FACE Prep Campus-ன் சிறப்பம்சங்கள்,\n\n1. Practical அடிப்படையிலான Learning.\n\n2.  தொழில்நுட்ப Skills (Artificial Intelligence, Machine Learning, Data Science மற்றும் Full Stack Development) degree உடன் வழங்கப்படும்.\n\n3. Graduation Certificate from College - Affiliated University.\n\n5. Industry Expertise Mentors \n\n6. இரண்டாம் ஆண்டு முடிவில் paid internship வாய்ப்புகள்.\n\n7. மாதம் 50,000 வரை சம்பளத்துடன் உறுதியளிக்கப்பட்ட வேலை வாய்ப்புகள்.\n\nFACE Prep Campus பற்றி மேலும் தெரிந்து கொள்ள, கீழே உள்ள link-ஐ click செய்யவும்: https://bit.ly/3Tms5Ef \n\nApplication Form-ஐ பெற, கீழே உள்ள link-ஐ click செய்யவும்:  https://pages.razorpay.com/pl_NAcDtbp7HpOxwA/view',
#   'Published_Date': '2024-01-10T13:16:35Z',
#   'Duration': 'PT3M48S',
#   'Views_Count': '294',
#   'Likes_Count': '17',
#   'Comments_Count': '2',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'w1aYdmAgrck',
#   'Video_Title': '12th Chemistry Important 2 Marks | Public Questions | Board Exams | FACE Prep Campus',
#   'Thumbnail': 'https://i.ytimg.com/vi/w1aYdmAgrck/default.jpg',
#   'Description': "📚Most Asked Public 2 Mark Questions in 12th Chemistry! \n\n📊📖 If you're a Tamil Nadu student gearing up for your exams, this video is your ultimate guide to nailing those critical 2-mark questions. 🎯 From essential concepts to insightful explanations, we've got you covered. Boost your confidence and ace your exams with FACE Prep Campus! 🚀📝\n\n#12thchemistry   #exampreparation  #tamilnadustudents  #topquestions  #faceprepcampus #educationmatters #Chemistry #chemistryquestions",
#   'Published_Date': '2024-01-09T13:47:12Z',
#   'Duration': 'PT54S',
#   'Views_Count': '656',
#   'Likes_Count': '51',
#   'Comments_Count': '6',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'sUb8SP_MEro',
#   'Video_Title': '12th Computer Science Important 3 Marks | Public Questions | Board Exams | 12th Students',
#   'Thumbnail': 'https://i.ytimg.com/vi/sUb8SP_MEro/default.jpg',
#   'Description': "📚Most Asked Public 3 Marks Questions in 12th Computer Science! \n\n📊📖 If you're a Tamil Nadu student gearing up for your exams, this video is your ultimate guide to nailing those critical 3-mark questions. 🎯 From essential concepts to insightful explanations, we've got you covered. Boost your confidence and ace your exams with FACE Prep Campus! 🚀📝\n\n#12thComputerscience  #exampreparation  #tamilnadustudents  #topquestions  #faceprepcampus #educationmatters #computerscience #computersciencequestions",
#   'Published_Date': '2024-01-08T11:30:27Z',
#   'Duration': 'PT1M',
#   'Views_Count': '683',
#   'Likes_Count': '81',
#   'Comments_Count': '4',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'bZ4z3M8lfAc',
#   'Video_Title': '12th Chemistry Important 3 Marks | Public Questions | Board Exams | 12th Students',
#   'Thumbnail': 'https://i.ytimg.com/vi/bZ4z3M8lfAc/default.jpg',
#   'Description': "📚Most Asked Public 3 Marks Questions in 12th Chemistry! \n\n📊📖 If you're a Tamil Nadu student gearing up for your exams, this video is your ultimate guide to nailing those critical 3-mark questions. 🎯 From essential concepts to insightful explanations, we've got you covered. Boost your confidence and ace your exams with FACE Prep Campus! 🚀📝\n\n#12thChemistry  #exampreparation  #tamilnadustudents  #topquestions  #faceprepcampus #educationmatters #chemistry #chemistryquestions",
#   'Published_Date': '2024-01-08T06:30:08Z',
#   'Duration': 'PT1M',
#   'Views_Count': '429',
#   'Likes_Count': '42',
#   'Comments_Count': '5',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'e4msUutQw_s',
#   'Video_Title': '12th Economics Important 2 Marks | Public Questions | FACE Prep Campus | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/e4msUutQw_s/default.jpg',
#   'Description': "📚Most Asked Public 2 Marks Questions in 12th Economics! \n\n📊📖 If you're a Tamil Nadu student gearing up for your exams, this video is your ultimate guide to nailing those critical 2-mark questions. 🎯 From essential concepts to insightful explanations, we've got you covered. Boost your confidence and ace your exams with FACE Prep Campus! 🚀📝\n\n#12theconomics  #exampreparation  #tamilnadustudents  #topquestions  #faceprepcampus #educationmatters #economics  #economicsquestions",
#   'Published_Date': '2024-01-07T13:57:39Z',
#   'Duration': 'PT55S',
#   'Views_Count': '588',
#   'Likes_Count': '48',
#   'Comments_Count': '1',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'aP7o5jKRmMM',
#   'Video_Title': '12th Commerce Important 2 Mark | Public Questions | Students | FACE Prep Campus',
#   'Thumbnail': 'https://i.ytimg.com/vi/aP7o5jKRmMM/default.jpg',
#   'Description': "📚Most Asked Public 2 Marks Questions in 12th Commerce! \n\n📊📖 If you're a Tamil Nadu student gearing up for your exams, this video is your ultimate guide to nailing those critical 2-mark questions. 🎯 From essential concepts to insightful explanations, we've got you covered. Boost your confidence and ace your exams with FACE Prep Campus! 🚀📝\n\n#12thCommerce  #exampreparation  #tamilnadustudents  #topquestions  #faceprepcampus #educationmatters #commerce #commercequestions",
#   'Published_Date': '2024-01-06T13:37:09Z',
#   'Duration': 'PT54S',
#   'Views_Count': '294',
#   'Likes_Count': '34',
#   'Comments_Count': '4',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'VXUpCXrwpOQ',
#   'Video_Title': '12th PHYSICS Important 2 Marks | Public Questions | Students | FACE Prep Campus',
#   'Thumbnail': 'https://i.ytimg.com/vi/VXUpCXrwpOQ/default.jpg',
#   'Description': "📚Most Asked Public 2 Marks Questions in 12th Physics! \n\n📊📖 If you're a Tamil Nadu student gearing up for your exams, this video is your ultimate guide to nailing those critical 2-mark questions. 🎯 From essential concepts to insightful explanations, we've got you covered. Boost your confidence and ace your exams with FACE Prep Campus! 🚀📝\n\n#12thphysics   #exampreparation  #tamilnadustudents  #topquestions  #faceprepcampus #educationmatters #physics #physicsquestions",
#   'Published_Date': '2024-01-05T12:35:20Z',
#   'Duration': 'PT58S',
#   'Views_Count': '569',
#   'Likes_Count': '50',
#   'Comments_Count': '6',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': '0pGntFqkEUk',
#   'Video_Title': '12th Computer Science Important 2 Mark Questions | Public Exam | Students | FACE Prep Campus | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/0pGntFqkEUk/default.jpg',
#   'Description': "📚Most Asked Public 2 Marks Questions in 12th Computer Science! \n\n📊📖 If you're a Tamil Nadu student gearing up for your exams, this video is your ultimate guide to nailing those critical 2-mark questions. 🎯 From essential concepts to insightful explanations, we've got you covered. Boost your confidence and ace your exams with FACE Prep Campus! 🚀📝\n\n#12thcomputerscience   #exampreparation  #tamilnadustudents  #topquestions  #faceprepcampus #educationmatters #computerscience #computersciencequestions",
#   'Published_Date': '2024-01-03T05:46:40Z',
#   'Duration': 'PT1M',
#   'Views_Count': '1204',
#   'Likes_Count': '115',
#   'Comments_Count': '2',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'cgKDZpL4oHM',
#   'Video_Title': 'Why Data Science is Important? | Scope | FACE Prep Campus | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/cgKDZpL4oHM/default.jpg',
#   'Description': 'தமிழகத்தின் best job-oriented computer science degree program-ஐ வழங்கும் FACE Prep Campus-ன் சிறப்பம்சங்கள்,\n\n1. Practical அடிப்படையிலான Learning.\n\n2.  தொழில்நுட்ப Skills (Artificial Intelligence, Machine Learning, Data Science மற்றும் Full Stack Development) degree உடன் வழங்கப்படும்.\n\n3. Graduation Certificate from College - Affiliated University.\n\n5. Industry Expertise Mentors \n\n6. இரண்டாம் ஆண்டு முடிவில் paid internship வாய்ப்புகள்.\n\n7. மாதம் 50,000 வரை சம்பளத்துடன் உறுதியளிக்கப்பட்ட வேலை வாய்ப்புகள்.\n\nFACE Prep Campus பற்றி மேலும் தெரிந்து கொள்ள, கீழே உள்ள link-ஐ click செய்யவும்: https://bit.ly/3Tms5Ef \n\nApplication Form-ஐ பெற, கீழே உள்ள link-ஐ click செய்யவும்:  https://pages.razorpay.com/pl_NAcDtbp7HpOxwA/view',
#   'Published_Date': '2024-01-02T10:47:41Z',
#   'Duration': 'PT1M36S',
#   'Views_Count': '277',
#   'Likes_Count': '18',
#   'Comments_Count': '1',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'BMIWwPtO5C0',
#   'Video_Title': 'Importance of Indemand Technologies | FACE Prep Campus | Placement Assured | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/BMIWwPtO5C0/default.jpg',
#   'Description': 'தமிழகத்தின் best job-oriented computer science degree program-ஐ வழங்கும் FACE Prep Campus-ன் சிறப்பம்சங்கள்,\n\n1. Practical அடிப்படையிலான Learning.\n\n2.  தொழில்நுட்ப Skills (Artificial Intelligence, Machine Learning, Data Science மற்றும் Full Stack Development) degree உடன் வழங்கப்படும்.\n\n3. Graduation Certificate from College - Affiliated University.\n\n5. Industry Expertise Mentors \n\n6. இரண்டாம் ஆண்டு முடிவில் paid internship வாய்ப்புகள்.\n\n7. மாதம் 50,000 வரை சம்பளத்துடன் உறுதியளிக்கப்பட்ட வேலை வாய்ப்புகள்.\n\nFACE Prep Campus பற்றி மேலும் தெரிந்து கொள்ள, கீழே உள்ள link-ஐ click செய்யவும்: https://bit.ly/3Tms5Ef \n\nApplication Form-ஐ பெற, கீழே உள்ள link-ஐ click செய்யவும்:  https://pages.razorpay.com/pl_NAcDtbp7HpOxwA/view',
#   'Published_Date': '2023-12-30T06:16:37Z',
#   'Duration': 'PT42S',
#   'Views_Count': '318',
#   'Likes_Count': '19',
#   'Comments_Count': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'O-XZXza-7PE',
# ...
#   'Thumbnail': 'https://i.ytimg.com/vi/gVkQ9lgxmLw/default.jpg',
#   'Description': "How to Start learning coding? \n\n🚀💻 In this Tamil video, we're discussing about the secrets of how to kickstart your programming adventure, even if you're new to the world of coding. 🌟 \n\nDesigned especially for 12th standard students and non-technical enthusiasts, this video provides step-by-step guidance on taking those crucial first steps into the exciting realm of programming languages.\n\nDiscover the fundamentals of coding languages and learn valuable tips to overcome any initial challenges. Whether you've never written a line of code or you're looking to strengthen your coding skills, this video is your compass.\n\nLet's turn your coding curiosity into a powerful skill set that opens doors to endless possibilities! 🔐🔍💡\n\n#LearnToCode #ProgrammingBeginners #CodingJourney #TamilTutorial #TechForNonTechies #12thStdStudents #CodingAdventure #DigitalSkills",
#   'Published_Date': '2023-08-21T12:30:16Z',
#   'Duration': 'PT2M45S',
#   'Views_Count': '253',
#   'Likes_Count': '17',
#   'Comments_Count': '1',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': '4-yjDSMKSjM',
#   'Video_Title': 'What is B.Sc. Computer Science? | Details | Opportunities after 12th | Degree Guidance | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/4-yjDSMKSjM/default.jpg',
#   'Description': "What is  B.Sc. Computer Science?\n\n🖥️🎓 In this Tamil video, we're discussing about the essence of B.Sc. Computer Science - its Course details, opportunities, and vast scope. \n\n#bsccomputerscience  #EducationExploration #tamileducation  #limitlessscope #careeropportunities  #computerscience",
#   'Published_Date': '2023-08-19T12:52:28Z',
#   'Duration': 'PT3M33S',
#   'Views_Count': '168',
#   'Likes_Count': '12',
#   'Comments_Count': '1',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': '9UkPS-WPFLQ',
#   'Video_Title': 'How to choose degree & college after 12th Std? | 2024 College Admission Details | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/9UkPS-WPFLQ/default.jpg',
#   'Description': 'How to choose degree & college after 12th Std?\n\n🎓 In this video we unravel the intricate tapestry of College Admission Process 2024!\n\nDiscover expert tips on selecting the perfect college, explore scholarship opportunities that pave the way, and gain valuable insights into degree guidance. 🌟 Whether you\'re a student or a parent, this comprehensive guide is your compass to navigate the exciting road ahead. Let\'s make your academic dreams a reality together! 🚀📚\n\n #CollegeAdmission2024 #DegreeGuidance #Scholarships #EducationJourney"',
#   'Published_Date': '2023-08-18T11:34:14Z',
#   'Duration': 'PT2M48S',
#   'Views_Count': '203',
#   'Likes_Count': '9',
#   'Comments_Count': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': '74EMZCEnGt0',
#   'Video_Title': 'Most asked 5 marks questions in 12th Commerce | FACE Prep Campus | Tamil  #exampreparation',
#   'Thumbnail': 'https://i.ytimg.com/vi/74EMZCEnGt0/default.jpg',
#   'Description': "📚Most Asked 5 Marks Questions in 12th Commerce! \n\n📊📖 If you're a Tamil Nadu student gearing up for your exams, this video is your ultimate guide to nailing those critical 5-mark questions. 🎯 From essential concepts to insightful explanations, we've got you covered. Boost your confidence and ace your exams with FACE Prep Campus! 🚀📝\n\n#12thcommerce  #exampreparation  #tamilnadustudents  #topquestions  #FACEPrepCampus",
#   'Published_Date': '2023-08-17T13:18:35Z',
#   'Duration': 'PT1M28S',
#   'Views_Count': '113',
#   'Likes_Count': '5',
#   'Comments_Count': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'ftGFKNsRKpU',
#   'Video_Title': 'Most asked 5 marks questions in 12th computer science | FACE Prep Campus | Tamil  #exampreparation',
#   'Thumbnail': 'https://i.ytimg.com/vi/ftGFKNsRKpU/default.jpg',
#   'Description': "📚🖥️ Master Your 12th Computer Science Exam: Most Asked 5-Marks Questions!\n\nCalling all Tamil Nadu students! 🎓 Striving for success in your computer science exam? In this Video we discussed the most commonly asked 5-marks questions that could make all the difference in your score. Get ready to level up your preparation with valuable insights and expert guidance. Don't miss out on this essential session to boost your confidence and excel in your exams! 🌟\n\n#tamilnadustudents  #12thcomputerscience  #exampreparation  #toppertips  #studysmart  #examsuccess  #computersciencequestions #tamilnadueducation  #scorehigh  #exampreparation  #studyhacks  #studentlife  #academicexcellence  #tamilnaduboardexams #5marksquestions #studymotivation  #learnwithus  #youtubetutorial  #educationalvideo  #studentsupport  #studyguide",
#   'Published_Date': '2023-08-16T10:45:45Z',
#   'Duration': 'PT56S',
#   'Views_Count': '37602',
#   'Likes_Count': '2628',
#   'Comments_Count': '28',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'A7U6B7bkTmY',
#   'Video_Title': 'How to become topper | Students Hacks | FACE Prep Campus | Tamil #educationmatters',
#   'Thumbnail': 'https://i.ytimg.com/vi/A7U6B7bkTmY/default.jpg',
#   'Description': "Master the Art of Academic Excellence!\n\nAttention, school students! 🎓 Ready to ace your studies and reach the top? Join us as we unravel the secrets of becoming a successful topper. From study techniques to time management, we've got you covered. This video is your ultimate guide to achieving academic greatness. Tune in and elevate your path to success! 🌟",
#   'Published_Date': '2023-08-15T05:33:00Z',
#   'Duration': 'PT57S',
#   'Views_Count': '352',
#   'Likes_Count': '37',
#   'Comments_Count': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'IfGIq6R7Vyg',
#   'Video_Title': 'How to memorize easily | Students Hacks | Tamil | FACE Prep Campus',
#   'Thumbnail': 'https://i.ytimg.com/vi/IfGIq6R7Vyg/default.jpg',
#   'Description': "🎓Welcome to FACE Prep Campus! Your Learning Partner for Success.\n\n🧠 Mastering Memory Hacks: Unlock Easy Memorization Techniques!\n\nAttention, students! 📚 Are you Struggling to remember things? Don't worry, In this Video we are going to tell simple yet powerful hacks to supercharge your memory skills. \n\nThis special video made for school students, is your key to acing exams and boosting your learning journey. Get ready to discover the art of easy memorization! 🌟",
#   'Published_Date': '2023-08-10T09:19:56Z',
#   'Duration': 'PT57S',
#   'Views_Count': '316',
#   'Likes_Count': '34',
#   'Comments_Count': '4',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'mgV8YODTIMk',
#   'Video_Title': "What is Cloud Computing? | Scope and it's Courses | Career Opportunities after 12th | Tamil",
#   'Thumbnail': 'https://i.ytimg.com/vi/mgV8YODTIMk/default.jpg',
#   'Description': 'Welcome to FACE Prep Campus, In this Video let\'s Explore Cloud Computing - A Glimpse into the Future of Technology!\n\nEver wondered what\'s behind the term "cloud computing"? 🤔 Get ready for a fascinating journey where we unravel its secrets, discover its amazing possibilities, and introduce you to exciting courses. \n\nThis is perfect for 12th std students who want to step into the tech world. Join us as we dive into the world of cloud computing and set the stage for your tech-filled tomorrow! 🌟',
#   'Published_Date': '2023-08-09T13:08:36Z',
#   'Duration': 'PT3M33S',
#   'Views_Count': '97',
#   'Likes_Count': '10',
#   'Comments_Count': '0',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'IGG0ZaDol3g',
#   'Video_Title': 'How to learn Coding for Beginners | Opportunities after 12th | Tamil | FACE Prep Campus',
#   'Thumbnail': 'https://i.ytimg.com/vi/IGG0ZaDol3g/default.jpg',
#   'Description': "Beginner's Guide to Learning Coding! 📚\n\nAre you a school student eager to dive into the world of coding? 🚀 In this video, we'll unravel step-by-step strategies and essential tips to kickstart your coding journey. From choosing the right language to mastering fundamental concepts, get ready to embark on an exciting path to becoming a coding wizard! 🌟\n\nSubscribe now and unlock the secrets to conquering coding as a beginner. Let's turn your coding dreams into reality! 💻🔓 #CodingForBeginners #LearnToCode #EducationMatters",
#   'Published_Date': '2023-08-08T08:08:14Z',
#   'Duration': 'PT3M9S',
#   'Views_Count': '279',
#   'Likes_Count': '24',
#   'Comments_Count': '7',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'sMMjqvuCb6w',
#   'Video_Title': 'Does Coding have a Future? | Career Opportunities after 12th | FACE Prep Campus | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/sMMjqvuCb6w/default.jpg',
#   'Description': "🌐🤖 Welcome to our YouTube channel, In this Video we are going to explore the future of coding\n\nIs coding here to stay, or is it just a passing trend? 🤔 In this captivating video, we discuss the exciting world of coding, exploring its impact on industries, careers, and innovation. Join us as we uncover why coding is not just a skill, but a key to shaping the future! 🔑\n\nSubscribe now and gain insights into the boundless opportunities that coding offers in the ever-evolving landscape of technology. Let's decode the future together! 🌟\n\n#CodingFuture #TechInnovation #EducationMatters",
#   'Published_Date': '2023-08-07T06:50:58Z',
#   'Duration': 'PT1M',
#   'Views_Count': '237',
#   'Likes_Count': '24',
#   'Comments_Count': '4',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'Q42SjnkAgNE',
#   'Video_Title': 'Python or Java | Coding for Beginners | Career Opportunities after 12th | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/Q42SjnkAgNE/default.jpg',
#   'Description': "🐍🆚☕ Python or Java? Discover the Perfect Choice for 12th Students! 🎓\n\nConfused about which programming language to learn - Python or Java? 🤔 In this video, we'll explore the ease of learning, versatility, and real-world applications of both languages, helping you make an informed decision to kickstart your coding journey! 🚀\n\nSubscribe now and unravel the secrets behind Python and Java, as we guide you toward a rewarding and successful path in programming! 🔥 #PythonVsJava #CodingJourney #EducationMatters",
#   'Published_Date': '2023-08-05T10:29:42Z',
#   'Duration': 'PT52S',
#   'Views_Count': '58200',
#   'Likes_Count': '3925',
#   'Comments_Count': '32',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'E6R92j2LStc',
#   'Video_Title': 'Data science | Career Opportunities after 12th | Course details | Scope | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/E6R92j2LStc/default.jpg',
#   'Description': "📊 Unleash the Power of Data Science - Your Gateway to the Future! 🌐\n\nWelcome to FACE Prep Campus, In this Video we unravel the fascinating world of Data Science and its boundless opportunities! 🚀\n\n📚 Course Details: Dive into the immersive Data Science curriculum, covering data analysis, machine learning, AI, and more. Prepare to embark on a transformative learning journey.\n\n🎯 Career Insights: Discover the vast career prospects that Data Science offers, from data analysts to AI engineers. Explore how this field is reshaping industries worldwide.\n\n💡 Real-World Applications: Witness Data Science in action through inspiring real-world examples and case studies that showcase its impact on businesses and society.\n\n🌟 Expert Perspectives: Learn from Data Science experts who share their insights, experiences, and tips for aspiring data enthusiasts.\n\n🎓 Your Path to Success: Whether you're a student or professional, we guide you through the Data Science course details to empower your career growth.\n\nReady to unlock the power of data and make an impact on the world? 📊 Subscribe now and join the Data Science community as we explore the limitless possibilities together!\n\nDon't miss out on this exclusive video that opens doors to a world of data-driven opportunities. Hit the notification bell to stay updated with our latest uploads, and let's shape the future with Data Science! \n\n#DataScience #DataDrivenFuture #EducationMatters",
#   'Published_Date': '2023-08-04T09:13:12Z',
#   'Duration': 'PT2M38S',
#   'Views_Count': '359',
#   'Likes_Count': '19',
#   'Comments_Count': '1',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'gNVPDnOGJrY',
#   'Video_Title': 'Artificial Intelligence | Career Opportunities after 12th | Course details | Scope | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/gNVPDnOGJrY/default.jpg',
#   'Description': "Artificial Intelligence - Your Gateway to a Futuristic Career! 🤖\n\nWelcome to our YouTube channel, In this Video we explore the exciting realm of Artificial Intelligence (AI) and its vast scope after 12th! 🌐\n\n🎯 Career Opportunities: Discover diverse AI career paths and opportunities that await you in this cutting-edge field.\n\n🌟 Industry Insights: Gain invaluable insights from AI experts driving innovation and shaping the future.\n\n💡 Why AI Matters: Explore AI's transformative impact across industries and its potential for a better world.\n\n🎓 Guiding Your Path: We'll equip students and parents with AI course details for a promising future.\n\nJoin us on this exciting journey into the AI-powered future! 🚀 Subscribe now and hit the bell icon for updates!\n\n#AIforFuture #AIInnovations #EducationMatters",
#   'Published_Date': '2023-08-03T09:49:27Z',
#   'Duration': 'PT3M10S',
#   'Views_Count': '310',
#   'Likes_Count': '15',
#   'Comments_Count': '2',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'},
#  {'Channel_Name': 'FACE Prep Campus',
#   'Channel_ID': 'UC9kKt-14c3tjGJSO_jwPHnA',
#   'Video_ID': 'mYvuAGVd_ZE',
#   'Video_Title': 'FACE Prep Campus | Introduction | Career Counseling | Tamil',
#   'Thumbnail': 'https://i.ytimg.com/vi/mYvuAGVd_ZE/default.jpg',
#   'Description': "Welcome to FACE Prep Campus, your ultimate destination for academic excellence and personal growth. Our channel is made for +11 and +12 school students, offering a diverse range of educational content, campus life insights, career guidance, and computer science hacks.\n\nJoin us as we embark on an enriching learning adventure together! Subscribe now to unlock a world of possibilities and stay updated with our latest uploads. Let's make your school days unforgettable and your future brighter than ever before!\n\nSubscribe to FACE Prep Campus now and step into a world of limitless potential. #FACEPrepCampus #EducationMatters #StudySmart",
#   'Published_Date': '2023-07-28T11:31:32Z',
#   'Duration': 'PT1M14S',
#   'Views_Count': '733',
#   'Likes_Count': '12',
#   'Comments_Count': '2',
#   'Favourite_Count': '0',
#   'Definition': 'hd',
#   'Caption_Status': 'false'}]

# %%
# Function for getting Comments Details :

def get_comment_info(video_ids):
    Comment_data = []
    try:
        for video_id in video_ids :
            request = youtube.commentThreads().list(part = 'snippet',
                                                    videoId = video_id,
                                                    maxResults = 50)
            response = request.execute()
            
            for i in response['items']:
                data = dict(Comment_ID = i['snippet']['topLevelComment']['id'],
                            Video_ID = i['snippet']['topLevelComment']['snippet']['videoId'],
                            Comment_Text = i['snippet']['topLevelComment']['snippet']['textDisplay'],
                            Comment_Author = i['snippet']['topLevelComment']['snippet']['authorDisplayName'],
                            Comment_Published= i['snippet']['topLevelComment']['snippet']['publishedAt'])
    
                Comment_data.append(data)
    except :
        pass
    return  Comment_data

# %%
comment_details= get_comment_info(Video_Ids)

# %%
comment_details
# Out:
# [{'Comment_ID': 'Ugy50gd_OU5lyKgzm-t4AaABAg',
#   'Video_ID': 'dA4XM5u-6Oc',
#   'Comment_Text': '👏',
#   'Comment_Author': '@villan407n3',
#   'Comment_Published': '2024-05-08T06:01:16Z'},
#  {'Comment_ID': 'UgyzP2sNLB4pn72IC0R4AaABAg',
#   'Video_ID': 'G9OEsPZGVWs',
#   'Comment_Text': 'Hai',
#   'Comment_Author': '@Murugandevi5214Murugan',
#   'Comment_Published': '2024-05-18T12:08:01Z'},
#  {'Comment_ID': 'UgwAcIgtPLMToWcAdKh4AaABAg',
#   'Video_ID': 'G9OEsPZGVWs',
#   'Comment_Text': 'Akka iam 10th std write public exam<br>Next 11th i take course computers course . I take what section take? Please tell',
#   'Comment_Author': '@HARISCARFAMILY',
#   'Comment_Published': '2024-04-24T18:24:55Z'},
#  {'Comment_ID': 'UgxtW254lY0WL7h400d4AaABAg',
#   'Video_ID': 'G9OEsPZGVWs',
#   'Comment_Text': 'Hi',
#   'Comment_Author': '@sureshtiwari4432',
#   'Comment_Published': '2024-04-24T13:08:03Z'},
#  {'Comment_ID': 'Ugzk6-oQTSg-w5BW5e54AaABAg',
#   'Video_ID': 'G9OEsPZGVWs',
#   'Comment_Text': 'Hi',
#   'Comment_Author': '@sureshtiwari4432',
#   'Comment_Published': '2024-04-24T13:06:47Z'},
#  {'Comment_ID': 'Ugzvmm9lKvyJbvqHtsh4AaABAg',
#   'Video_ID': 'G9OEsPZGVWs',
#   'Comment_Text': 'Hi',
#   'Comment_Author': '@lakshmiarts8045',
#   'Comment_Published': '2024-04-17T10:27:59Z'},
#  {'Comment_ID': 'UgxbWCgRIGm5s9nJDKp4AaABAg',
#   'Video_ID': 'G9OEsPZGVWs',
#   'Comment_Text': 'Hi mam , face prep campus  kite collegela availabla iruka mam?',
#   'Comment_Author': '@MohanaKumar-jo3vx',
#   'Comment_Published': '2024-04-15T07:33:16Z'},
#  {'Comment_ID': 'UgyPpag1Hr-fSKtyBPl4AaABAg',
#   'Video_ID': 'G9OEsPZGVWs',
#   'Comment_Text': 'Hi',
#   'Comment_Author': '@Flower-wu8bg',
#   'Comment_Published': '2024-04-15T05:01:07Z'},
#  {'Comment_ID': 'UgxK64-vECECAJgqgDx4AaABAg',
#   'Video_ID': '6tGfa9aepz0',
#   'Comment_Text': 'Maths is compulsory??',
#   'Comment_Author': '@SREELAKSHMI.M.V',
#   'Comment_Published': '2024-05-18T05:00:14Z'},
#  {'Comment_ID': 'UgxuEwdwM3dRYnHs2fN4AaABAg',
#   'Video_ID': '6tGfa9aepz0',
#   'Comment_Text': 'Cut off mark evlo akka',
#   'Comment_Author': '@shalinis7718',
#   'Comment_Published': '2024-05-06T11:09:20Z'},
#  {'Comment_ID': 'UgwL8DxHWsVHsi-gkcF4AaABAg',
#   'Video_ID': 'Il-Wd_88fZE',
#   'Comment_Text': 'Thank you mam',
#   'Comment_Author': '@karneshsenthamil4381',
#   'Comment_Published': '2024-03-19T09:59:30Z'},
#  {'Comment_ID': 'UgxBuZPe9iFIqJs26tp4AaABAg',
#   'Video_ID': 'TDYtHZAaxHw',
#   'Comment_Text': 'Face prep laa join panlaama ❤❤❤❤',
#   'Comment_Author': '@murugan2678',
#   'Comment_Published': '2024-03-17T16:49:05Z'},
#  {'Comment_ID': 'Ugxyv2F8IbebdHxfrU14AaABAg',
#   'Video_ID': 'UEa9eeClLFI',
#   'Comment_Text': '10.8 la irunthu question varama irukathu..aprm 6.7 9.8 9.9',
#   'Comment_Author': '@balajibalaj6118',
#   'Comment_Published': '2024-03-17T23:57:27Z'},
#  {'Comment_ID': 'UgyHiRYJR1Q_5WzKOjF4AaABAg',
#   'Video_ID': 'UEa9eeClLFI',
#   'Comment_Text': 'Mm ok❤',
#   'Comment_Author': '@mama.94',
#   'Comment_Published': '2024-03-15T10:02:15Z'},
#  {'Comment_ID': 'UgwvRkWDGCC_P2krdUF4AaABAg',
#   'Video_ID': 'TKfiti3_vyY',
#   'Comment_Text': 'Sir Itha Pathi...Neraya Peruku Theriyarathu ila..ithu Maari Neraya ...Full Classification video..Parents ooda Podunga Sir..👍🏼',
#   'Comment_Author': '@kamaleshp5633',
#   'Comment_Published': '2024-03-18T05:29:55Z'},
#  {'Comment_ID': 'Ugyy85rQ13AYT4gb41J4AaABAg',
#   'Video_ID': 'PwOrzH4g2Dg',
#   'Comment_Text': 'Akka 12th zoo sollunga for long version coming 19',
#   'Comment_Author': '@selviprakash-vm2fp',
#   'Comment_Published': '2024-03-15T11:18:51Z'},
#  {'Comment_ID': 'UgxN6Mq9FoIfcn52TgV4AaABAg',
#   'Video_ID': 'PwOrzH4g2Dg',
#   'Comment_Text': 'Use ful tips',
#   'Comment_Author': '@Ranjithmuthu03',
#   'Comment_Published': '2024-03-13T01:15:30Z'},
#  {'Comment_ID': 'UgwocOhVdYqjpxPZtu54AaABAg',
#   'Video_ID': 'PwOrzH4g2Dg',
#   'Comment_Text': 'Tq mam',
#   'Comment_Author': '@Ranjithmuthu03',
#   'Comment_Published': '2024-03-13T01:15:10Z'},
#  {'Comment_ID': 'Ugzw1omg6cbRYl4ysrJ4AaABAg',
#   'Video_ID': '7gNXXeDUhe8',
#   'Comment_Text': 'Ithu maari neraya ..Eduthu Podunga...Sir',
#   'Comment_Author': '@kamaleshp5633',
#   'Comment_Published': '2024-03-17T15:02:43Z'},
#  {'Comment_ID': 'UgzMuKj2HuwR5Chru4R4AaABAg',
#   'Video_ID': 'gckt7y6TqYo',
#   'Comment_Text': 'Mam this is enough ahh',
#   'Comment_Author': '@vkghostgaming4362',
#   'Comment_Published': '2024-03-08T13:17:18Z'},
#  {'Comment_ID': 'UgzITFwK9JidzTswiTx4AaABAg',
#   'Video_ID': 'apekYaY2ZGE',
#   'Comment_Text': 'Mam i am class study12th in conmerce with computer application group naan BCA padikalama',
#   'Comment_Author': '@aloneff724',
#   'Comment_Published': '2024-04-12T09:07:19Z'},
#  {'Comment_ID': 'UgyrOFGLN37E0Frexyd4AaABAg',
#   'Video_ID': 'apekYaY2ZGE',
#   'Comment_Text': 'Fee structure enna mam? And join panna entrance irukaa?',
#   'Comment_Author': '@learnnewtamil',
#   'Comment_Published': '2024-03-19T14:31:26Z'},
#  {'Comment_ID': 'UgzS6_aYMKT_4MNjb1B4AaABAg',
#   'Video_ID': 'apekYaY2ZGE',
#   'Comment_Text': 'You guys doing Cs dgree in tier 4 college right ?',
#   'Comment_Author': '@user-ci1tz1xj6u',
#   'Comment_Published': '2024-03-15T07:29:57Z'},
#  {'Comment_ID': 'UgxsMfsz_o8kyndgbT54AaABAg',
#   'Video_ID': 'qUJTkohDOxc',
#   'Comment_Text': 'Akka, in Kanniyakumari district will you launch the BCA courses',
#   'Comment_Author': '@Flower-wu8bg',
#   'Comment_Published': '2024-04-15T05:07:16Z'},
#  {'Comment_ID': 'UgyRltnfuuWhccwQXv94AaABAg',
#   'Video_ID': 'qUJTkohDOxc',
#   'Comment_Text': 'Hi FPC',
#   'Comment_Author': '@rakshana-id9cc',
#   'Comment_Published': '2024-04-04T10:17:55Z'},
#  {'Comment_ID': 'UgzqcM4ZEj7JaAPB4D94AaABAg',
#   'Video_ID': 'qUJTkohDOxc',
#   'Comment_Text': 'Akka BSC IT course available? In kamaraj college',
#   'Comment_Author': '@jenithkumar7855',
#   'Comment_Published': '2024-04-04T08:40:25Z'},
#  {'Comment_ID': 'UgyWvnlZowYkSezZfxB4AaABAg',
#   'Video_ID': 'qUJTkohDOxc',
#   'Comment_Text': 'Akka face prep campus pondicherry la irukka',
#   'Comment_Author': '@mr.kalakkalcomedy855',
#   'Comment_Published': '2024-03-05T16:24:54Z'},
#  {'Comment_ID': 'UgwN7e4vDNchnF5Ut4p4AaABAg',
#   'Video_ID': 'qUJTkohDOxc',
#   'Comment_Text': 'Akka naa 11th padikire face prep campus la padika evlo fees one year ku',
#   'Comment_Author': '@gopi5919',
#   'Comment_Published': '2024-02-29T05:54:24Z'},
#  {'Comment_ID': 'Ugz9Ad5-NwtFM7axoz14AaABAg',
#   'Video_ID': 'CP2Me9AUPA0',
#   'Comment_Text': 'Hi',
#   'Comment_Author': '@thameemansari421',
#   'Comment_Published': '2024-04-30T09:53:34Z'},
#  {'Comment_ID': 'UgyH0qz5yeMFG9CIyGR4AaABAg',
#   'Video_ID': 'CP2Me9AUPA0',
#   'Comment_Text': 'Hi',
#   'Comment_Author': '@ihwaryamarisamy3219',
#   'Comment_Published': '2024-04-27T12:40:39Z'},
#  {'Comment_ID': 'UgwnFVAwFYqii_27gwZ4AaABAg',
#   'Video_ID': 'CP2Me9AUPA0',
#   'Comment_Text': 'Hi fpc',
#   'Comment_Author': '@AravindAravind-sc7lt',
#   'Comment_Published': '2024-03-31T10:28:15Z'},
#  {'Comment_ID': 'UgyIVCCNn0wnl6BMP9V4AaABAg',
#   'Video_ID': 'CP2Me9AUPA0',
#   'Comment_Text': 'Hi',
#   'Comment_Author': '@AravindAravind-sc7lt',
#   'Comment_Published': '2024-03-31T10:28:02Z'},
#  {'Comment_ID': 'UgwxvzU6gF8R72ductV4AaABAg',
#   'Video_ID': 'CP2Me9AUPA0',
#   'Comment_Text': 'Is there any entrance exam',
#   'Comment_Author': '@user-wb5oe4hc2e',
#   'Comment_Published': '2024-02-27T09:08:10Z'},
#  {'Comment_ID': 'Ugx-sUL4VDKwYCpe3Vp4AaABAg',
#   'Video_ID': 'CP2Me9AUPA0',
#   'Comment_Text': 'What is the fees structure of FacePrep Campus',
#   'Comment_Author': '@user-wb5oe4hc2e',
#   'Comment_Published': '2024-02-27T09:07:55Z'},
#  {'Comment_ID': 'Ugwzc-dvDaTnB6tRz1R4AaABAg',
#   'Video_ID': '78WxtTkcIgI',
#   'Comment_Text': 'Hi',
#   'Comment_Author': '@akash-wf4jj',
#   'Comment_Published': '2024-05-12T15:01:19Z'},
#  {'Comment_ID': 'UgzpeNE-xEuEtcqmv6J4AaABAg',
#   'Video_ID': '78WxtTkcIgI',
#   'Comment_Text': 'Hi FPC . <br>Evlo mark eduthalum padikalama. Fees evlo irukum',
#   'Comment_Author': '@rakshana-id9cc',
#   'Comment_Published': '2024-04-04T10:10:18Z'},
#  {'Comment_ID': 'Ugym_7RzwAF04WnvKYt4AaABAg',
#   'Video_ID': '78WxtTkcIgI',
#   'Comment_Text': 'Hi FPC',
#   'Comment_Author': '@user-cm2my9dj2h',
#   'Comment_Published': '2024-03-07T14:00:48Z'},
#  {'Comment_ID': 'UgxAKlLRwf5YwENaQ7F4AaABAg',
#   'Video_ID': 'Mj4qBRthUZI',
#   'Comment_Text': 'Enda pacha poii pesra 😂😂( Regarding placements)',
#   'Comment_Author': '@Ytube__student',
#   'Comment_Published': '2024-02-16T16:46:18Z'},
#  {'Comment_ID': 'UgxCTqe7M9uFMJBaQQt4AaABAg',
#   'Video_ID': '8vjRNzQwdy8',
#   'Comment_Text': 'Can you launch BCA in Kanniyakumari with face prep campus',
#   'Comment_Author': '@Flower-wu8bg',
#   'Comment_Published': '2024-04-15T05:03:18Z'},
#  {'Comment_ID': 'Ugzr7bSITdsWLH8b2ah4AaABAg',
#   'Video_ID': '8vjRNzQwdy8',
#   'Comment_Text': 'Hi FPC',
#   'Comment_Author': '@KUMARESANBALRAJ-yh7wk',
#   'Comment_Published': '2024-04-06T05:40:23Z'},
#  {'Comment_ID': 'Ugy9HJm5kPjCv7DolQF4AaABAg',
#   'Video_ID': '8vjRNzQwdy8',
#   'Comment_Text': 'Hi FPC',
#   'Comment_Author': '@KUMARESANBALRAJ-yh7wk',
#   'Comment_Published': '2024-04-06T05:40:08Z'},
#  {'Comment_ID': 'UgyO7Yu5KAS-Te0tfD14AaABAg',
#   'Video_ID': '8vjRNzQwdy8',
#   'Comment_Text': 'Hi FPC',
#   'Comment_Author': '@KUMARESANBALRAJ-yh7wk',
#   'Comment_Published': '2024-04-06T05:39:33Z'},
#  {'Comment_ID': 'Ugw_IYnFwXWkz54NMS94AaABAg',
#   'Video_ID': 'B06aRs1rvKg',
#   'Comment_Text': 'Msc. Cs eruka',
#   'Comment_Author': '@ArunKumar-wh1iu',
#   'Comment_Published': '2024-05-13T14:51:59Z'},
#  {'Comment_ID': 'UgxDzGNkYid1g7S9dXx4AaABAg',
#   'Video_ID': 'B06aRs1rvKg',
#   'Comment_Text': 'Hi',
#   'Comment_Author': '@akash-wf4jj',
#   'Comment_Published': '2024-05-12T15:05:02Z'},
#  {'Comment_ID': 'UgzXcvBfzzjw6o9INkV4AaABAg',
#   'Video_ID': 'B06aRs1rvKg',
#   'Comment_Text': 'Fpc',
#   'Comment_Author': '@Foodtraveltalkiesbyshahanaz',
#   'Comment_Published': '2024-05-12T09:25:56Z'},
#  {'Comment_ID': 'UgymVRtvTe_ggokGCud4AaABAg',
#   'Video_ID': 'B06aRs1rvKg',
#   'Comment_Text': '❤❤❤',
#   'Comment_Author': '@alertaravinth9628',
#   'Comment_Published': '2024-03-09T18:41:51Z'},
#  {'Comment_ID': 'Ugx0rkZ5-84uaDhK4gV4AaABAg',
#   'Video_ID': 'Hi_CwdFlpKg',
#   'Comment_Text': 'Hi',
#   'Comment_Author': '@user-yh8yn3lu5p',
#   'Comment_Published': '2024-04-04T07:20:59Z'},
#  {'Comment_ID': 'Ugx0ACbSqsph10u0bBp4AaABAg',
#   'Video_ID': 'Hi_CwdFlpKg',
#   'Comment_Text': 'Commerce students join panalama akka',
#   'Comment_Author': '@LokeshVaran-gf6qe',
#   'Comment_Published': '2024-03-25T05:02:20Z'},
#  {'Comment_ID': 'UgyfQwvdxDoxLAfVGHB4AaABAg',
#   'Video_ID': 'Hi_CwdFlpKg',
#   'Comment_Text': 'Hi',
#   'Comment_Author': '@cybertech7551',
#   'Comment_Published': '2024-03-13T10:31:09Z'},
#  {'Comment_ID': 'Ugx2qX9XhhXjKjeWjN14AaABAg',
#   'Video_ID': 'x7Ub1LkrKVE',
#   'Comment_Text': 'Hi fpc',
#   'Comment_Author': '@MithraMithra-xh7gi',
#   'Comment_Published': '2024-05-05T10:13:42Z'},
#  {'Comment_ID': 'Ugwb5g-XzQ4dHqRL0Kt4AaABAg',
#   'Video_ID': 'x7Ub1LkrKVE',
#   'Comment_Text': 'Hi FPC',
#   'Comment_Author': '@AugastinM',
#   'Comment_Published': '2024-04-07T04:16:11Z'},
#  {'Comment_ID': 'UgxxTBTVhzdKTVYnddl4AaABAg',
#   'Video_ID': 'x7Ub1LkrKVE',
#   'Comment_Text': 'Interesting! Need to know more about it..',
#   'Comment_Author': '@SaravananRamasamy30101982',
#   'Comment_Published': '2024-02-14T11:16:24Z'},
#  {'Comment_ID': 'Ugx1KiRnKIW10vUlqr14AaABAg',
#   'Video_ID': '2LnOlUvkZ9M',
#   'Comment_Text': 'FPC',
#   'Comment_Author': '@bepositive153',
#   'Comment_Published': '2024-04-01T13:28:17Z'},
#  {'Comment_ID': 'Ugw-w9GKadFzRlsnHBp4AaABAg',
#   'Video_ID': '2LnOlUvkZ9M',
#   'Comment_Text': 'Hi',
#   'Comment_Author': '@ashokramesh3561',
#   'Comment_Published': '2024-03-31T04:59:44Z'},
#  {'Comment_ID': 'UgyWlp02TVkWKa_uo794AaABAg',
#   'Video_ID': '2LnOlUvkZ9M',
#   'Comment_Text': '&#39;PromoSM&#39; 😕',
#   'Comment_Author': '@darrel888',
#   'Comment_Published': '2024-03-05T05:10:36Z'},
#  {'Comment_ID': 'UgzfVw6pOXcYsdcREkl4AaABAg',
#   'Video_ID': '2LnOlUvkZ9M',
#   'Comment_Text': 'Hi but college la ketta avungalukku etha pathi ethuvum theriyala , neenga only final year la mattum thaan varuveenga nnu solranga',
#   'Comment_Author': '@KrishAkash-ie4tr',
#   'Comment_Published': '2024-02-22T07:54:36Z'},
#  {'Comment_ID': 'UgxNdMvbUhTQgCVTMJ14AaABAg',
#   'Video_ID': '2LnOlUvkZ9M',
#   'Comment_Text': 'Hi',
#   'Comment_Author': '@KrishAkash-ie4tr',
#   'Comment_Published': '2024-02-21T16:15:07Z'},
#  {'Comment_ID': 'UgxT80rmTjXLfXLcq8x4AaABAg',
#   'Video_ID': '2LnOlUvkZ9M',
#   'Comment_Text': 'Any College in dharmapuri?',
#   'Comment_Author': '@Praveenkumar45582',
#   'Comment_Published': '2024-02-18T14:25:42Z'},
#  {'Comment_ID': 'Ugw2v09mEbUSRoXfI-J4AaABAg',
#   'Video_ID': '2LnOlUvkZ9M',
#   'Comment_Text': 'Any colleges in Coimbatore?',
#   'Comment_Author': '@anusuyac7092',
#   'Comment_Published': '2024-02-14T03:58:36Z'},
#  {'Comment_ID': 'UgzTghCoyGaWvWeTUI94AaABAg',
#   'Video_ID': '2LnOlUvkZ9M',
#   'Comment_Text': 'Chennai la indha madrie iruka bca without maths',
#   'Comment_Author': '@mahalakshmiramesh1906',
#   'Comment_Published': '2024-02-13T14:07:17Z'},
#  {'Comment_ID': 'UgzCWJVq1O_MWlDuzZp4AaABAg',
#   'Video_ID': 'y6LW8wtGIgM',
#   'Comment_Text': 'tamil',
#   'Comment_Author': '@user-ki2sb1qo4q',
#   'Comment_Published': '2024-03-11T13:22:19Z'},
#  {'Comment_ID': 'Ugy3HZ3Cu5khQ1JTTcp4AaABAg',
#   'Video_ID': 'y6LW8wtGIgM',
#   'Comment_Text': 'Ena course padicha ah benift',
#   'Comment_Author': '@safrinjeba6304',
#   'Comment_Published': '2024-03-07T17:36:15Z'},
#  {'Comment_ID': 'UgwLSInxaH74U66s1KN4AaABAg',
#   'Video_ID': 'y6LW8wtGIgM',
#   'Comment_Text': 'Bio computer edutha ena padikalam ,atha padicha evalavu salery ,ethu useful ah irukum nu solunga mam plss',
#   'Comment_Author': '@safrinjeba6304',
#   'Comment_Published': '2024-03-07T17:35:11Z'},
#  {'Comment_ID': 'UgzLAk8-dpHDI9Dpa_p4AaABAg',
#   'Video_ID': 'y6LW8wtGIgM',
#   'Comment_Text': 'Akka this is enough ahh',
#   'Comment_Author': '@vkghostgaming4362',
#   'Comment_Published': '2024-03-07T14:43:08Z'},
#  {'Comment_ID': 'UgyjPAlJFFCx8Q44wXp4AaABAg',
#   'Video_ID': 'y6LW8wtGIgM',
#   'Comment_Text': 'Akka ithe mari important questions poduga',
#   'Comment_Author': '@r33epo_edits',
#   'Comment_Published': '2024-03-07T12:56:05Z'},
#  {'Comment_ID': 'UgwgCHkPXoR-vKRhEn94AaABAg',
#   'Video_ID': 'y6LW8wtGIgM',
#   'Comment_Text': '12th computer application important 2m,3m,5m today upload pannuga plz',
#   'Comment_Author': '@nilavarnisha9928',
#   'Comment_Published': '2024-03-07T05:34:04Z'},
#  {'Comment_ID': 'UgxvhL0RVPc0TIv4_IR4AaABAg',
#   'Video_ID': 'y6LW8wtGIgM',
#   'Comment_Text': 'Can you upload a videos for cs compulsory ques',
#   'Comment_Author': '@Andrewtatefan0001',
#   'Comment_Published': '2024-03-05T13:40:59Z'},
#  {'Comment_ID': 'UgwQXCynJtBIrOqKMkZ4AaABAg',
#   'Video_ID': 'y6LW8wtGIgM',
#   'Comment_Text': 'Tq akka for imp questions and you so sweet and your look like an  angel  princess ❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤😊😊😊😊😊😊😊😊😊❤❤❤❤',
#   'Comment_Author': '@mohammedaahil5705',
#   'Comment_Published': '2024-02-27T07:43:02Z'},
#  {'Comment_ID': 'UgwwUNxofYEb_iKCRdt4AaABAg',
#   'Video_ID': 'y6LW8wtGIgM',
#   'Comment_Text': 'Can you give maths important question',
#   'Comment_Author': '@hajirakhatoon8922',
#   'Comment_Published': '2024-02-18T04:30:54Z'},
#  {'Comment_ID': 'UgxI1zgC9vISnlWwtv14AaABAg',
#   'Video_ID': 'y6LW8wtGIgM',
#   'Comment_Text': 'Maths important solluga kka please.... Neega sonna tha maths padika start pannum please',
#   'Comment_Author': '@roobia2357',
#   'Comment_Published': '2024-02-15T16:31:24Z'},
#  {'Comment_ID': 'UgwmxD4kds6W81SKsth4AaABAg',
#   'Video_ID': 'y6LW8wtGIgM',
#   'Comment_Text': 'Mam cyclotron question important ahh',
#   'Comment_Author': '@Ranjithmuthu03',
#   'Comment_Published': '2024-02-13T03:49:08Z'},
#  {'Comment_ID': 'Ugyz7eV8H9V3abnRMxR4AaABAg',
#   'Video_ID': 'y6LW8wtGIgM',
#   'Comment_Text': 'Tks akka idhe marri video podunga',
#   'Comment_Author': '@riyasriyas997',
#   'Comment_Published': '2024-02-03T06:02:08Z'},
#  {'Comment_ID': 'UgwYJ7iXzjq_Ngq8S354AaABAg',
#   'Video_ID': 'y6LW8wtGIgM',
#   'Comment_Text': 'Thanks akka',
#   'Comment_Author': '@Rahaman2530',
#   'Comment_Published': '2024-01-30T16:53:29Z'},
#  {'Comment_ID': 'UgwJF4ziL0hT_f49i294AaABAg',
#   'Video_ID': '877t1yyKwkI',
#   'Comment_Text': 'Mam 10 question important ahha mam',
#   'Comment_Author': '@Ranjithmuthu03',
#   'Comment_Published': '2024-03-07T06:34:07Z'},
#  {'Comment_ID': 'UgyuZjJvPPxC0PNuJdh4AaABAg',
#   'Video_ID': '877t1yyKwkI',
#   'Comment_Text': 'Tamil 😢',
#   'Comment_Author': '@rohith3827',
#   'Comment_Published': '2024-03-06T08:48:58Z'},
#  {'Comment_ID': 'Ugyqso0xw58O0cGLbut4AaABAg',
#   'Video_ID': '877t1yyKwkI',
#   'Comment_Text': 'Important chapter enna enna sis❤',
#   'Comment_Author': '@karthee_____x',
#   'Comment_Published': '2024-01-31T15:54:59Z'},
#  {'Comment_ID': 'Ugz7sv4sM0B4Px8vcFp4AaABAg',
#   'Video_ID': '877t1yyKwkI',
#   'Comment_Text': 'Kaa arts ku intha Mari videos poduga ka',
#   'Comment_Author': '@maskersmystery4241',
#   'Comment_Published': '2024-01-23T01:50:49Z'},
#  {'Comment_ID': 'UgzQFJH8gIxV8mSTWv54AaABAg',
#   'Video_ID': '877t1yyKwkI',
#   'Comment_Text': 'Akka public cs important questions 2,3,5 mark video venum plzzz',
#   'Comment_Author': '@deepandeepan5094',
#   'Comment_Published': '2024-01-22T14:35:34Z'},
#  {'Comment_ID': 'UgxS4tglzjnrOdii8RF4AaABAg',
#   'Video_ID': '877t1yyKwkI',
#   'Comment_Text': 'Mam, Important compulsory questions upload pannunga mam And compulsory program also',
#   'Comment_Author': '@jaya2083',
#   'Comment_Published': '2024-01-19T16:00:50Z'},
#  {'Comment_ID': 'UgwC5qgAUismNjxjv9N4AaABAg',
#   'Video_ID': 'qFAaBX0OXko',
#   'Comment_Text': 'Akka neega sonathula 4 detail vadhurichi akka',
#   'Comment_Author': '@user-fz9vy2lg8q',
#   'Comment_Published': '2024-03-18T17:03:08Z'},
#  {'Comment_ID': 'UgxtAGyHds-6czhDUIF4AaABAg',
#   'Video_ID': 'qFAaBX0OXko',
#   'Comment_Text': 'Akka 😂crta 2 vanthuchi neega sonnathula',
#   'Comment_Author': '@user-wj3rb8wh2m',
#   'Comment_Published': '2024-03-17T04:41:54Z'},
#  {'Comment_ID': 'UgzMEcIUKNoj07YssmN4AaABAg',
#   'Video_ID': 'qFAaBX0OXko',
#   'Comment_Text': 'Tamil medium podunga Akka 12 th',
#   'Comment_Author': '@user-do2eg8hm6n',
#   'Comment_Published': '2024-03-15T01:46:18Z'},
#  {'Comment_ID': 'UgziM_qii1EaFfwuygZ4AaABAg',
#   'Video_ID': 'qFAaBX0OXko',
#   'Comment_Text': 'Important 3mark',
#   'Comment_Author': '@RNL_fun_gaming',
#   'Comment_Published': '2024-03-14T11:04:38Z'},
#  {'Comment_ID': 'UgwMIu7vENsciZHcV-J4AaABAg',
#   'Video_ID': 'qFAaBX0OXko',
#   'Comment_Text': 'Akka ithula ethana vera vaipu iruku',
#   'Comment_Author': '@user-wj3rb8wh2m',
#   'Comment_Published': '2024-03-13T05:27:42Z'},
#  {'Comment_ID': 'Ugz_wN82ZOli_vifv1h4AaABAg',
#   'Video_ID': 'qFAaBX0OXko',
#   'Comment_Text': 'Important 3 mark Akka',
#   'Comment_Author': '@rameshdharshini8787',
#   'Comment_Published': '2024-03-12T09:38:49Z'},
#  {'Comment_ID': 'Ugz5-qJVMP_J0pS4bXh4AaABAg',
#   'Video_ID': 'qFAaBX0OXko',
#   'Comment_Text': 'Commerce , accounts,computer application,economics  2,3,5 marks important for public questions please  upload',
#   'Comment_Author': '@malinid5467',
#   'Comment_Published': '2024-02-25T05:18:44Z'},
#  {'Comment_ID': 'UgyiKrvb9s45l-pw_Bt4AaABAg',
#   'Video_ID': 'qFAaBX0OXko',
#   'Comment_Text': 'Tamil please',
#   'Comment_Author': '@Aarthigaarthi-tg9yv',
#   'Comment_Published': '2024-01-22T10:42:48Z'},
#  {'Comment_ID': 'Ugxritf8egRBu_8MeEF4AaABAg',
#   'Video_ID': 'qFAaBX0OXko',
#   'Comment_Text': 'Akka 2 mark and mark um poduga ka 🕊️',
#   'Comment_Author': '@Student20064',
#   'Comment_Published': '2024-01-18T14:37:55Z'},
#  {'Comment_ID': 'UgwHkPIEjZY8rK0CUt94AaABAg',
#   'Video_ID': 'AnORSQMvbco',
#   'Comment_Text': 'Important 2 &amp; 3 solunga akka',
#   'Comment_Author': '@_insta_ajay_17',
#   'Comment_Published': '2024-03-09T13:25:37Z'},
#  {'Comment_ID': 'UgwLEiyec2v67aIc6YJ4AaABAg',
#   'Video_ID': 'AnORSQMvbco',
#   'Comment_Text': 'Akka this is very important question akka',
#   'Comment_Author': '@aithampattupernambut7149',
#   'Comment_Published': '2024-03-09T09:10:19Z'},
#  {'Comment_ID': 'UgxRcSwQTe87J2tjlu94AaABAg',
#   'Video_ID': 'AnORSQMvbco',
#   'Comment_Text': 'akkkaa edhuu confirm public ku padichitu polaamaa akkaaa',
#   'Comment_Author': '@EAshwiniEAshwini',
#   'Comment_Published': '2024-03-07T20:50:01Z'},
#  {'Comment_ID': 'UgxgLDPLmE16xqNbKkd4AaABAg',
#   'Video_ID': 'AnORSQMvbco',
#   'Comment_Text': 'Mam organic Important questions confirm in public',
#   'Comment_Author': '@MSGAMING-jj2nf',
#   'Comment_Published': '2024-02-26T16:52:18Z'},
#  {'Comment_ID': 'Ugz2WPufSubQfjtYChp4AaABAg',
#   'Video_ID': 'AnORSQMvbco',
#   'Comment_Text': 'Akka ithu mattum padicha pothuma',
#   'Comment_Author': '@dharshu467',
#   'Comment_Published': '2024-01-26T15:21:59Z'},
#  {'Comment_ID': 'UgyNiiRGX1BtP-W2LBV4AaABAg',
#   'Video_ID': 'AnORSQMvbco',
#   'Comment_Text': '12th chemistry organic lesson important equation solluga',
#   'Comment_Author': '@Smart_Kutty_06',
#   'Comment_Published': '2024-01-18T12:34:55Z'},
#  {'Comment_ID': 'UgzEgYSVRMTMaUqbOct4AaABAg',
#   'Video_ID': 'AnORSQMvbco',
#   'Comment_Text': 'Tq ka ❤',
#   'Comment_Author': '@Smart_Kutty_06',
#   'Comment_Published': '2024-01-18T12:32:47Z'},
#  {'Comment_ID': 'UgxdLKl-jCEDu9hbYPJ4AaABAg',
#   'Video_ID': 'WS-5DtAqymM',
#   'Comment_Text': 'Bro neenge sonnathule just 1 tha vanthuchu😂 commerce public exam la',
#   'Comment_Author': '@suguna1357',
#   'Comment_Published': '2024-03-19T12:16:36Z'},
#  {'Comment_ID': 'UgxR_rTJtHMqba7kZ_V4AaABAg',
#   'Video_ID': 'WS-5DtAqymM',
#   'Comment_Text': 'Na tamil medium',
#   'Comment_Author': '@balajibalu8791',
#   'Comment_Published': '2024-03-18T17:30:42Z'},
#  {'Comment_ID': 'Ugz-DKL4aynlRN58kNt4AaABAg',
#   'Video_ID': 'WS-5DtAqymM',
#   'Comment_Text': 'Akka Tamil medium sollunga',
#   'Comment_Author': '@user-oi4rg3lv7h',
#   'Comment_Published': '2024-03-18T16:17:28Z'},
#  {'Comment_ID': 'UgzqQnaf3a1njH7cbUN4AaABAg',
#   'Video_ID': 'WS-5DtAqymM',
#   'Comment_Text': 'Akka love u so much ❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤❤',
#   'Comment_Author': '@MohanaPriyan-wi3wj',
#   'Comment_Published': '2024-03-18T08:31:40Z'},
#  {'Comment_ID': 'Ugz_BFzhF545k9iIGqp4AaABAg',
#   'Video_ID': 'WS-5DtAqymM',
#   'Comment_Text': 'Nega sonnathula ethana questions varum akka',
#   'Comment_Author': '@SelviSelvi-bz8eg',
#   'Comment_Published': '2024-03-18T05:51:57Z'},
#  {'Comment_ID': 'Ugwoj2n5P0zv4sz3jB14AaABAg',
#   'Video_ID': 'WS-5DtAqymM',
#   'Comment_Text': 'Akka ithula 2 varma 😅',
#   'Comment_Author': '@user-wj3rb8wh2m',
#   'Comment_Published': '2024-03-17T04:43:12Z'},
#  {'Comment_ID': 'Ugzsbn9QYnq9JHspXQx4AaABAg',
#   'Video_ID': 'WS-5DtAqymM',
#   'Comment_Text': 'Tamila sollukaa',
#   'Comment_Author': '@elumalaid2h565',
#   'Comment_Published': '2024-03-16T07:07:40Z'},
#  {'Comment_ID': 'UgxfRhviBd52C4rI8oh4AaABAg',
#   'Video_ID': 'WS-5DtAqymM',
#   'Comment_Text': '12th computer application important questions upload pannuga akka pliss',
#   'Comment_Author': '@Student20064',
#   'Comment_Published': '2024-01-29T21:06:16Z'},
#  {'Comment_ID': 'UgwyJ3C6N43JiyF0Evh4AaABAg',
#   'Video_ID': 'WS-5DtAqymM',
#   'Comment_Text': '1. functions of SEBI<br>2.consumers are exploited <br>3.challenges face by women entrepreneurs <br>4.highlight of LBG<br>These are important or not!!!',
#   'Comment_Author': '@rsmariarts2187',
#   'Comment_Published': '2024-01-21T11:28:07Z'},
#  {'Comment_ID': 'UgwJb6aWjcrLl3a66I54AaABAg',
#   'Video_ID': 'nCYtXDLkBBc',
#   'Comment_Text': '2,3,5m important questions upload pannunga sis',
#   'Comment_Author': '@SakthiVel-lw6cb',
#   'Comment_Published': '2024-03-13T12:09:18Z'},
#  {'Comment_ID': 'Ugz6W9a0PKLjX3WikH54AaABAg',
#   'Video_ID': 'nCYtXDLkBBc',
#   'Comment_Text': 'Full syllabus video podugà',
#   'Comment_Author': '@Priya2007-go1sv',
#   'Comment_Published': '2024-03-12T10:23:28Z'},
#  {'Comment_ID': 'UgyVZMx9_iYPHvf3lQ54AaABAg',
#   'Video_ID': 'anQAMsAXVHs',
#   'Comment_Text': 'Akka chemistry 2days matutha iruku study plan potutharvingala',
#   'Comment_Author': '@r33epo_edits',
#   'Comment_Published': '2024-03-07T13:27:36Z'},
#  {'Comment_ID': 'UgxHQmw8AnB2bt8LQC94AaABAg',
#   'Video_ID': 'anQAMsAXVHs',
#   'Comment_Text': 'There will be only theory or only problems. Please can u say which one will be more asked',
#   'Comment_Author': '@VarshaaM-pc6lr',
#   'Comment_Published': '2024-01-28T02:09:48Z'},
#  {'Comment_ID': 'Ugzi7oCHlEnijm6Q6Hl4AaABAg',
#   'Video_ID': 'anQAMsAXVHs',
#   'Comment_Text': '12 th physics centum vanguradukku questions kunga mam...plz',
#   'Comment_Author': '@ibrahimprints5094',
#   'Comment_Published': '2024-01-19T16:05:59Z'},
#  {'Comment_ID': 'UgxN4MovBCbChFGlaXt4AaABAg',
#   'Video_ID': 'anQAMsAXVHs',
#   'Comment_Text': '12th maths how to take 75+ please upload video 😢',
#   'Comment_Author': '@user-cy8vo9dx3d',
#   'Comment_Published': '2024-01-15T23:53:52Z'},
#  {'Comment_ID': 'UgwOmeZ6pnE07elKM5x4AaABAg',
#   'Video_ID': 'zPdnlEvWKD0',
#   'Comment_Text': 'Anather important questions for 3marks mam',
#   'Comment_Author': '@anbuselvam9885',
#   'Comment_Published': '2024-03-16T01:33:50Z'},
#  {'Comment_ID': 'UgxQRMejYbsj7BM19kF4AaABAg',
#   'Video_ID': '2Y6PRWVk1Ng',
#   'Comment_Text': 'Top engineering colleges in coimbatore 2024 videos podunga akkaa..........',
#   'Comment_Author': '@user-si8wv7me3n',
#   'Comment_Published': '2024-02-05T23:51:16Z'},
#  {'Comment_ID': 'UgxpUXseGMRgFoGmKq14AaABAg',
#   'Video_ID': '2Y6PRWVk1Ng',
#   'Comment_Text': 'Why Nobody Support here😢',
#   'Comment_Author': '@sltamizha9950',
#   'Comment_Published': '2024-01-10T13:50:27Z'},
#  {'Comment_ID': 'UgxK_Zu9OJGT9wu20bB4AaABAg',
#   'Video_ID': 'w1aYdmAgrck',
#   'Comment_Text': 'Thank you',
#   'Comment_Author': '@user-zo3vu9lb6w',
#   'Comment_Published': '2024-02-13T15:26:51Z'},
#  {'Comment_ID': 'UgzXDBdA_ImVa41FcMV4AaABAg',
#   'Video_ID': 'w1aYdmAgrck',
#   'Comment_Text': 'Mam I wanna score centum in chemistry...so give that questions',
#   'Comment_Author': '@ibrahimprints5094',
#   'Comment_Published': '2024-01-19T16:07:12Z'},
#  {'Comment_ID': 'Ugy47-agstoZGy_dNq54AaABAg',
#   'Video_ID': 'w1aYdmAgrck',
#   'Comment_Text': 'Confirm varum sis😢',
#   'Comment_Author': '@dhivyabalakrishnan6440',
#   'Comment_Published': '2024-01-11T00:51:53Z'},
#  {'Comment_ID': 'UgyVbW9MOGIaMJmLXZx4AaABAg',
#   'Video_ID': 'w1aYdmAgrck',
#   'Comment_Text': 'Thanks Ka❤',
#   'Comment_Author': '@ModernMaverickss',
#   'Comment_Published': '2024-01-09T17:20:25Z'},
#  {'Comment_ID': 'UgxgNLPLUfSf9aRRXpp4AaABAg',
#   'Video_ID': 'sUb8SP_MEro',
#   'Comment_Text': 'Yes',
#   'Comment_Author': '@appuarmyyt5694',
#   'Comment_Published': '2024-03-06T14:23:30Z'},
#  {'Comment_ID': 'UgyflTL3HqTtabGGNtl4AaABAg',
#   'Video_ID': 'sUb8SP_MEro',
#   'Comment_Text': 'Yes',
#   'Comment_Author': '@MahaDevan-tp4sv',
#   'Comment_Published': '2024-01-11T00:10:36Z'},
#  {'Comment_ID': 'Ugw0ytBkfytdo-kWpaR4AaABAg',
#   'Video_ID': 'sUb8SP_MEro',
#   'Comment_Text': 'Is 5th and 10th are same question? 🤔',
#   'Comment_Author': '@sathya5937',
#   'Comment_Published': '2024-01-10T15:40:06Z'},
#  {'Comment_ID': 'Ugxx9oY7D232Q7EYZq14AaABAg',
#   'Video_ID': 'bZ4z3M8lfAc',
#   'Comment_Text': 'Yes',
#   'Comment_Author': '@mhamednaveed7292',
#   'Comment_Published': '2024-03-05T12:45:41Z'},
#  {'Comment_ID': 'UgzIeVi2sGsCc_2HJuF4AaABAg',
#   'Video_ID': 'bZ4z3M8lfAc',
#   'Comment_Text': 'Yes',
#   'Comment_Author': '@daughterofworldcreator',
#   'Comment_Published': '2024-01-18T14:02:12Z'},
#  {'Comment_ID': 'UgyACCk3LrTuHk-Is394AaABAg',
#   'Video_ID': 'bZ4z3M8lfAc',
#   'Comment_Text': 'Itha matum padicha pothu ma😢',
#   'Comment_Author': '@dhivyabalakrishnan6440',
#   'Comment_Published': '2024-01-11T00:55:29Z'},
#  {'Comment_ID': 'UgzSgpkWfbb49dSt2TJ4AaABAg',
#   'Video_ID': 'bZ4z3M8lfAc',
#   'Comment_Text': 'Yes',
#   'Comment_Author': '@Queenby591',
#   'Comment_Published': '2024-01-09T01:01:45Z'},
#  {'Comment_ID': 'Ugyo3wSQtcLf1lcJZ-F4AaABAg',
#   'Video_ID': 'e4msUutQw_s',
#   'Comment_Text': 'Tnx Akka ❤🤗',
#   'Comment_Author': '@user-ly5su7so8u',
#   'Comment_Published': '2024-03-12T02:30:22Z'},
#  {'Comment_ID': 'Ugzs-v-SuWIE8dbZ6Ah4AaABAg',
#   'Video_ID': 'aP7o5jKRmMM',
#   'Comment_Text': 'Please Tamil la anupunga',
#   'Comment_Author': '@user-ss2pi8yt8p',
#   'Comment_Published': '2024-03-17T05:29:25Z'},
#  {'Comment_ID': 'Ugx_Y2FWvvbooARavCZ4AaABAg',
#   'Video_ID': 'aP7o5jKRmMM',
#   'Comment_Text': 'And your voice is so sweet and you look angle❤❤❤❤❤❤❤❤❤❤❤❤❤❤😊😊😊😊😊😊😊😊😊😊😊😊',
#   'Comment_Author': '@mohammedaahil5705',
#   'Comment_Published': '2024-02-27T07:40:10Z'},
#  {'Comment_ID': 'Ugz0zXgWflZLKxrsmQF4AaABAg',
#   'Video_ID': 'aP7o5jKRmMM',
#   'Comment_Text': 'Super sis tq for your imp questions',
#   'Comment_Author': '@mohammedaahil5705',
#   'Comment_Published': '2024-02-27T07:38:57Z'},
#  {'Comment_ID': 'UgykFaap2GAla3xbu5N4AaABAg',
#   'Video_ID': 'aP7o5jKRmMM',
#   'Comment_Text': 'Wow',
#   'Comment_Author': '@mohammedaahil5705',
#   'Comment_Published': '2024-02-27T07:38:16Z'},
#  {'Comment_ID': 'Ugx2w3J1f8GE292ESyx4AaABAg',
#   'Video_ID': 'VXUpCXrwpOQ',
#   'Comment_Text': 'Maths important questions sis',
#   'Comment_Author': '@sahan9168',
#   'Comment_Published': '2024-02-05T17:04:02Z'},
#  {'Comment_ID': 'UgxbP79TxgYs-_7SW9V4AaABAg',
#   'Video_ID': 'VXUpCXrwpOQ',
#   'Comment_Text': 'Sorry akka I am not 12 th',
#   'Comment_Author': '@user-tv2ul5gg8n',
#   'Comment_Published': '2024-01-08T15:44:19Z'},
#  {'Comment_ID': 'UgzdFN2o5VLg8nTIhUd4AaABAg',
#   'Video_ID': 'VXUpCXrwpOQ',
#   'Comment_Text': 'Evlo thana',
#   'Comment_Author': '@nandhini.p1645',
#   'Comment_Published': '2024-01-08T10:40:12Z'},
#  {'Comment_ID': 'UgzPQJZVZ5y8TVmgNEN4AaABAg',
#   'Video_ID': 'VXUpCXrwpOQ',
#   'Comment_Text': 'Mam Tamil medium ku podu ga pls🙏🙏🙏🙏🙏😙',
#   'Comment_Author': '@sivas-sj6ye',
#   'Comment_Published': '2024-01-05T12:48:07Z'},
#  {'Comment_ID': 'UgwziFdbGYgN9tWYVMl4AaABAg',
#   'Video_ID': '0pGntFqkEUk',
#   'Comment_Text': 'Important chapter',
#   'Comment_Author': '@alfathfashiontailoirsfarid6105',
#   'Comment_Published': '2024-03-06T13:58:20Z'},
#  {'Comment_ID': 'Ugzi1ELb4fiZCXYeDU14AaABAg',
#   'Video_ID': '0pGntFqkEUk',
#   'Comment_Text': 'Tamil la sollunga kaa..😊😊😊😊',
#   'Comment_Author': '@govinddon6847',
#   'Comment_Published': '2024-03-05T08:42:25Z'},
#  {'Comment_ID': 'UgxHYdnlkrDyxb0VXid4AaABAg',
#   'Video_ID': 'cgKDZpL4oHM',
#   'Comment_Text': '🤌💗',
#   'Comment_Author': '@Romeo23321',
#   'Comment_Published': '2024-01-30T17:23:49Z'},
#  {'Comment_ID': 'Ugwgtykg04oW1BhZTD94AaABAg',
#   'Video_ID': 'twwZWmG14Bk',
#   'Comment_Text': 'How to attend demo session mam❤❤❤',
#   'Comment_Author': '@murugan2678',
#   'Comment_Published': '2023-12-26T14:53:49Z'},
#  {'Comment_ID': 'UgwQbN_HgjBFRJw2_Ed4AaABAg',
#   'Video_ID': 'GA3JGMHH7cU',
#   'Comment_Text': 'What is diff between software engineering and comp. Sci engineering akka',
#   'Comment_Author': '@Surya_pika',
#   'Comment_Published': '2023-12-27T13:53:07Z'},
#  {'Comment_ID': 'Ugw7k94b4CS8MeIxcqx4AaABAg',
#   'Video_ID': 'R5CiVduw518',
#   'Comment_Text': 'Send Hi&#39; to the no. 7904318695 to get the link  (or)  Check our YouTube Community to get the link.',
#   'Comment_Author': '@faceprepcampus',
#   'Comment_Published': '2023-12-20T13:36:50Z'},
#  {'Comment_ID': 'Ugwel4ZBD88He3qxf0l4AaABAg',
#   'Video_ID': 'R5CiVduw518',
#   'Comment_Text': 'Akka neenga.sema azhaga irukeenga',
#   'Comment_Author': '@ashwingameralways3243',
#   'Comment_Published': '2023-12-21T00:29:47Z'},
#  {'Comment_ID': 'UgyCNi6nDxaIUVPXWnh4AaABAg',
#   'Video_ID': 'rrYNBwihi9w',
#   'Comment_Text': 'ok akka',
#   'Comment_Author': '@balajibalajid-ym7xm',
#   'Comment_Published': '2023-12-15T13:04:51Z'},
#  {'Comment_ID': 'UgymnLdrwvuhPL9DOXV4AaABAg',
#   'Video_ID': '96YgBXe17No',
#   'Comment_Text': 'Mam commerce students can take bca',
#   'Comment_Author': '@aloneff724',
#   'Comment_Published': '2024-04-12T09:09:45Z'},
#  {'Comment_ID': 'UgxYzn3o_iKzVz9DgP54AaABAg',
#   'Video_ID': '-yknBskYJps',
#   'Comment_Text': 'Tamil medium paducha student la padikalama',
#   'Comment_Author': '@butterfly6717',
#   'Comment_Published': '2024-04-03T03:55:49Z'},
#  {'Comment_ID': 'UgzQTKx0nC1FpAiONrp4AaABAg',
#   'Video_ID': 'eUhhKkK4el0',
#   'Comment_Text': 'Super ka❤',
#   'Comment_Author': '@ashwingameralways3243',
#   'Comment_Published': '2023-12-21T00:32:54Z'},
#  {'Comment_ID': 'UgyF_iBxa90tKHEN6qB4AaABAg',
#   'Video_ID': 'raguvLZ0wK0',
#   'Comment_Text': 'Kov mass ka nee 😂',
#   'Comment_Author': '@Student20064',
#   'Comment_Published': '2023-12-14T12:13:52Z'},
#  {'Comment_ID': 'UgwNfcM-wH03ay7Zytt4AaABAg',
#   'Video_ID': 'qsoIE6zEdLs',
#   'Comment_Text': 'Neenga yenga school la cs edutha naan centum thaan yeduppen akka ☺️',
#   'Comment_Author': '@RomanReigns-vx2nb',
#   'Comment_Published': '2023-12-15T04:27:41Z'},
#  {'Comment_ID': 'UgyCA68zfF7jKP5Euox4AaABAg',
#   'Video_ID': 'qsoIE6zEdLs',
#   'Comment_Text': 'Akka i need to talk to you some doubts plzz ka jow to contact you personally 😢',
#   'Comment_Author': '@kasamusagaming302',
#   'Comment_Published': '2023-12-07T20:28:55Z'},
#  {'Comment_ID': 'UgwxerS8xCCKyJ0L0pl4AaABAg',
#   'Video_ID': 'mQ08eT9zHyo',
#   'Comment_Text': 'course and placement ku guide panuvegala ?Contact number?',
#   'Comment_Author': '@VNM00152',
#   'Comment_Published': '2023-12-08T09:18:16Z'},
#  {'Comment_ID': 'Ugwbek8OnU1dVirZz594AaABAg',
#   'Video_ID': 'mQ08eT9zHyo',
#   'Comment_Text': 'Akka 12th computer application important questions upload pannuga video format la pls 2m ,3m5m',
#   'Comment_Author': '@Student20064',
#   'Comment_Published': '2023-12-05T22:38:33Z'},
#  {'Comment_ID': 'Ugxm1iwj6hYR25UQ50p4AaABAg',
#   'Video_ID': 'RNxHtyslru0',
#   'Comment_Text': 'Super pa',
#   'Comment_Author': '@user-qi5hd7qs4o',
#   'Comment_Published': '2023-12-15T13:42:36Z'},
#  {'Comment_ID': 'Ugx7UNNYGZun25Jbgl14AaABAg',
#   'Video_ID': '2VJSARfTt6s',
#   'Comment_Text': 'Sir thiruvallur la unga college irukka sir',
#   'Comment_Author': '@Shanjana1174',
#   'Comment_Published': '2024-04-12T05:59:32Z'},
#  {'Comment_ID': 'UgzzLDao7zSZBMvvjdB4AaABAg',
#   'Video_ID': '2VJSARfTt6s',
#   'Comment_Text': 'Sir Chennai la unga college irukka sollu inga sir',
#   'Comment_Author': '@Shanjana1174',
#   'Comment_Published': '2024-04-12T04:57:43Z'},
#  {'Comment_ID': 'Ugz29AsCtjHviytMRYh4AaABAg',
#   'Video_ID': '2VJSARfTt6s',
#   'Comment_Text': 'Entha district la unga college irukku sollu inga sir',
#   'Comment_Author': '@DarwinThilson',
#   'Comment_Published': '2024-03-25T15:55:39Z'},
#  {'Comment_ID': 'UgwDLjcWGRbKyQtMO3Z4AaABAg',
#   'Video_ID': '2VJSARfTt6s',
#   'Comment_Text': 'Sir trichy la unga college irukka sir',
#   'Comment_Author': '@DarwinThilson',
#   'Comment_Published': '2024-03-25T15:53:26Z'},
#  {'Comment_ID': 'Ugzc9kFn5CiInRPwOyx4AaABAg',
#   'Video_ID': '2mnzSm7vxLk',
#   'Comment_Text': 'Akka your native place',
#   'Comment_Author': '@balajibalajid-ym7xm',
#   'Comment_Published': '2023-12-04T13:34:49Z'},
#  {'Comment_ID': 'Ugxcjbam5O5V1uBAGcZ4AaABAg',
#   'Video_ID': '2mnzSm7vxLk',
#   'Comment_Text': 'super akka',
#   'Comment_Author': '@balajibalajid-ym7xm',
#   'Comment_Published': '2023-12-04T13:34:10Z'},
#  {'Comment_ID': 'UgzVKtTT1sdG9r-RkB54AaABAg',
#   'Video_ID': 'JBA8Et2cPGg',
#   'Comment_Text': '🎉akka',
#   'Comment_Author': '@jayanthipalanisamy1516',
#   'Comment_Published': '2024-03-06T16:45:39Z'},
#  {'Comment_ID': 'UgxYh5NGH_vxrPOKrKh4AaABAg',
#   'Video_ID': 'JBA8Et2cPGg',
#   'Comment_Text': 'Thanks akka',
#   'Comment_Author': '@divyarose.s4160',
#   'Comment_Published': '2023-12-14T11:20:26Z'},
#  {'Comment_ID': 'UgyOdolVvw4oY7rqDlx4AaABAg',
#   'Video_ID': 'JBA8Et2cPGg',
#   'Comment_Text': 'Thanks akka❤❤',
#   'Comment_Author': '@saravananSaravanan-ey5tn',
#   'Comment_Published': '2023-12-12T17:33:52Z'},
#  {'Comment_ID': 'Ugxvd7-8tVlh8gnOVpl4AaABAg',
#   'Video_ID': '47y7ZsQZqaU',
#   'Comment_Text': 'Thanks akka🎉🎉🎉🎉❤❤❤❤',
#   'Comment_Author': '@saravananSaravanan-ey5tn',
#   'Comment_Published': '2023-12-14T09:38:54Z'},
#  {'Comment_ID': 'Ugx_HSCK6znlpEEu5n14AaABAg',
#   'Video_ID': '47y7ZsQZqaU',
#   'Comment_Text': 'Tamil important class 12 poduvingala ❤❤❤',
#   'Comment_Author': '@murugan2678',
#   'Comment_Published': '2023-11-29T14:36:52Z'},
#  {'Comment_ID': 'UgxyGU_1bSVR7Gu65tF4AaABAg',
#   'Video_ID': 'JmgH7d1nQiA',
#   'Comment_Text': 'Good evening',
#   'Comment_Author': '@Dharun__creations',
#   'Comment_Published': '2023-11-24T13:17:12Z'},
#  {'Comment_ID': 'UgyxHmhTK1V3LB5mu8J4AaABAg',
#   'Video_ID': 'f3o_9JtaZgM',
#   'Comment_Text': 'Akka please post 11th maths half yearly exam preparation',
#   'Comment_Author': '@VGxFiRoZ',
#   'Comment_Published': '2023-11-29T09:13:05Z'},
#  {'Comment_ID': 'UgxVqzU-CRyRMdJYWKZ4AaABAg',
#   'Video_ID': 'f3o_9JtaZgM',
#   'Comment_Text': 'Akka compulsory question podunga',
#   'Comment_Author': '@user-pl2tj8fo7p',
#   'Comment_Published': '2023-11-26T04:00:49Z'},
#  {'Comment_ID': 'Ugzm_KfzmebfADebjAx4AaABAg',
#   'Video_ID': 'f3o_9JtaZgM',
#   'Comment_Text': 'Thank you so much mam 😊',
#   'Comment_Author': '@subashreesathish6427',
#   'Comment_Published': '2023-11-26T02:05:06Z'},
#  {'Comment_ID': 'Ugxbxya81Abpb8ElWiV4AaABAg',
#   'Video_ID': 'RAlMj6Pht9g',
#   'Comment_Text': 'Akka bio computer edutha ena padikalam',
#   'Comment_Author': '@safrinjeba6304',
#   'Comment_Published': '2024-03-07T17:30:15Z'},
#  {'Comment_ID': 'UgwvAznDYzjpzgxGlU94AaABAg',
#   'Video_ID': 'JSnlZJvPQhc',
#   'Comment_Text': 'akka  if we study this question we can get pass ha',
#   'Comment_Author': '@archanak6632',
#   'Comment_Published': '2023-11-26T06:58:47Z'},
#  {'Comment_ID': 'Ugwwk1EiLl89KeJHogZ4AaABAg',
#   'Video_ID': 'JSnlZJvPQhc',
#   'Comment_Text': 'Thanks akka',
#   'Comment_Author': '@user-cy8vo9dx3d',
#   'Comment_Published': '2023-11-22T13:48:08Z'},
#  {'Comment_ID': 'UgyNychKY2BdPssAzDV4AaABAg',
#   'Video_ID': '9aPROBCV9mI',
#   'Comment_Text': 'Make more videos for commerce students mam💖',
#   'Comment_Author': '@terrorfootballkingstfk2210',
#   'Comment_Published': '2024-05-04T15:55:37Z'},
#  {'Comment_ID': 'UgywQmmOOeWBQiNoEZh4AaABAg',
#   'Video_ID': '9aPROBCV9mI',
#   'Comment_Text': 'Akka tamil medium podunga plzz',
#   'Comment_Author': '@UmaMaheswari-kw6lf',
#   'Comment_Published': '2023-12-04T16:52:59Z'},
#  {'Comment_ID': 'UgzBCT2-Ts05yrxMI7p4AaABAg',
#   'Video_ID': '9aPROBCV9mI',
#   'Comment_Text': 'முடிந்தால் தமிழில் பதிவு செய்யுங்கள்',
#   'Comment_Author': '@hariharankumaresan8131',
#   'Comment_Published': '2023-11-30T14:50:09Z'},
#  {'Comment_ID': 'Ugz-03v-B9uJ1pp-YUd4AaABAg',
#   'Video_ID': 'GNf4RI22qdg',
#   'Comment_Text': 'Unga ellam videos um super akka..🥺🥰💙<br>But indha questions la varum la ka🥺',
#   'Comment_Author': '@mageshwari0505',
#   'Comment_Published': '2023-11-24T16:47:06Z'},
#  {'Comment_ID': 'UgyCi-b19krN_mLhOqZ4AaABAg',
#   'Video_ID': 'Y0uJHyc89qA',
#   'Comment_Text': 'Is it very important detail?',
#   'Comment_Author': '@user-vk3dq3cw5c',
#   'Comment_Published': '2023-12-06T14:48:29Z'},
#  {'Comment_ID': 'UgzZ16pxaMFslbtnzBZ4AaABAg',
#   'Video_ID': 'Y0uJHyc89qA',
#   'Comment_Text': 'Etha padicha pass ayilama',
#   'Comment_Author': '@smazy_afthar1478',
#   'Comment_Published': '2023-12-04T01:53:49Z'},
#  {'Comment_ID': 'UgxmGDFwEPNwERTzvdd4AaABAg',
#   'Video_ID': 'D2os6zM30ho',
#   'Comment_Text': 'd.325',
#   'Comment_Author': '@janakiramanp5279',
#   'Comment_Published': '2024-01-17T08:07:35Z'},
#  {'Comment_ID': 'UgxKkiK00A8O_aNjD2V4AaABAg',
#   'Video_ID': 'D2os6zM30ho',
#   'Comment_Text': '325',
#   'Comment_Author': '@janakiramanp5279',
#   'Comment_Published': '2024-01-17T08:06:50Z'},
#  {'Comment_ID': 'UgyKFXBgexRBsqGbwVZ4AaABAg',
#   'Video_ID': 'D2os6zM30ho',
#   'Comment_Text': '114',
#   'Comment_Author': '@sakthikalas6448',
#   'Comment_Published': '2023-12-14T14:45:50Z'},
#  {'Comment_ID': 'UgwSd0aCF2-q462NLUt4AaABAg',
#   'Video_ID': 'D2os6zM30ho',
#   'Comment_Text': 'b)114',
#   'Comment_Author': '@vaishnavi.r.s1194',
#   'Comment_Published': '2023-12-14T13:17:06Z'},
#  {'Comment_ID': 'Ugx3QnjerYRl5DUIpoR4AaABAg',
#   'Video_ID': 'D2os6zM30ho',
#   'Comment_Text': 'B 114',
#   'Comment_Author': '@prasantha2249',
#   'Comment_Published': '2023-11-24T15:17:24Z'},
#  {'Comment_ID': 'UgxMo1zivPtrUocy6pZ4AaABAg',
#   'Video_ID': 'D2os6zM30ho',
#   'Comment_Text': 'X = 19,Y=6<br>So product XY = 19*6 = 114',
#   'Comment_Author': '@user-fv8qo8do9u',
#   'Comment_Published': '2023-11-21T17:49:43Z'},
#  {'Comment_ID': 'UgwEKiTTpVSTi1bQ8j94AaABAg',
#   'Video_ID': 'D2os6zM30ho',
#   'Comment_Text': '325',
#   'Comment_Author': '@kavithakumar9881',
#   'Comment_Published': '2023-11-21T13:33:55Z'},
#  {'Comment_ID': 'UgzrHwgTZRE9FuABaHl4AaABAg',
#   'Video_ID': 'D2os6zM30ho',
#   'Comment_Text': '315',
#   'Comment_Author': '@skatersanthosh991',
#   'Comment_Published': '2023-11-20T06:12:00Z'},
#  {'Comment_ID': 'Ugz66b5kYp7IuZAJWFd4AaABAg',
#   'Video_ID': 'TBQRn-FuLNo',
#   'Comment_Text': 'true mam',
#   'Comment_Author': '@user-ot9es2yo7x',
#   'Comment_Published': '2023-11-25T06:27:09Z'},
#  {'Comment_ID': 'UgxExZ6NKCfihvut2a54AaABAg',
#   'Video_ID': 'IAoCf8mGlIw',
#   'Comment_Text': '2c',
#   'Comment_Author': '@skatersanthosh991',
#   'Comment_Published': '2023-11-19T15:02:15Z'},
#  {'Comment_ID': 'UgzSIGtL602hyg9ARCt4AaABAg',
#   'Video_ID': 'IAoCf8mGlIw',
#   'Comment_Text': '1b',
#   'Comment_Author': '@skatersanthosh991',
#   'Comment_Published': '2023-11-19T15:01:48Z'},
#  {'Comment_ID': 'UgwHgvYCNUtiYHlJC3x4AaABAg',
#   'Video_ID': 'IAoCf8mGlIw',
#   'Comment_Text': '1 b',
#   'Comment_Author': '@gowsik',
#   'Comment_Published': '2023-11-18T09:39:25Z'},
#  {'Comment_ID': 'Ugz0bISkM0PNZWtLnV54AaABAg',
#   'Video_ID': 'fuYQIzRffPg',
#   'Comment_Text': '1.c',
#   'Comment_Author': '@lakshmisankarlakshmi6165',
#   'Comment_Published': '2023-12-03T16:21:15Z'},
#  {'Comment_ID': 'UgyCdSPOH9Cl-RJXDXJ4AaABAg',
#   'Video_ID': 'fuYQIzRffPg',
#   'Comment_Text': '2. 128 bits',
#   'Comment_Author': '@balajibalajid-ym7xm',
#   'Comment_Published': '2023-11-18T07:58:53Z'},
#  {'Comment_ID': 'Ugz9sGFO06oGBpEecEF4AaABAg',
#   'Video_ID': 'fuYQIzRffPg',
#   'Comment_Text': '1.\xa0Dennis Ritchie',
#   'Comment_Author': '@balajibalajid-ym7xm',
#   'Comment_Published': '2023-11-18T07:57:35Z'},
#  {'Comment_ID': 'Ugy9ji-6-bcXKlR2rfV4AaABAg',
#   'Video_ID': 'raLzRgUr8uk',
#   'Comment_Text': 'Indha 🌏 world la tamil genius illaa',
#   'Comment_Author': '@user-wx1si9th6q',
#   'Comment_Published': '2023-11-20T20:57:02Z'},
#  {'Comment_ID': 'UgxMVhEgP0EnYNoB90R4AaABAg',
#   'Video_ID': 'SEWiVscDmcY',
#   'Comment_Text': 'Akka maths important questions ah sollunga ka ❤',
#   'Comment_Author': '@V3pradeesh',
#   'Comment_Published': '2024-02-04T03:45:39Z'},
#  {'Comment_ID': 'UgzYakK0K4jca5blO3B4AaABAg',
#   'Video_ID': 'SEWiVscDmcY',
#   'Comment_Text': 'Naanum tamil medium',
#   'Comment_Author': '@shanthosh6642',
#   'Comment_Published': '2023-11-23T01:30:07Z'},
#  {'Comment_ID': 'UgypzpaWjaGI4kcL6kx4AaABAg',
#   'Video_ID': 'SEWiVscDmcY',
#   'Comment_Text': 'Mam Tamil medium ku solla mudiuma please',
#   'Comment_Author': '@kaleeswarig1985',
#   'Comment_Published': '2023-11-20T02:27:43Z'},
#  {'Comment_ID': 'UgwNMQk4io8Rbzve1Pl4AaABAg',
#   'Video_ID': 'viT6gaAevoc',
#   'Comment_Text': 'Tq akka😊😊 please continue the work akka😊❤ it&#39; s tooooo useful sis❤❤❤❤❤❤❤❤',
#   'Comment_Author': '@user-pw5wi9vu8x',
#   'Comment_Published': '2023-11-19T15:11:12Z'}]

# %%
# Function for getting Playlist Details :

def get_playlist_details(channel_id):
    next_page_token = None
    playlist_data = []
    while True :
        request = youtube.playlists().list(part = 'snippet,contentDetails',
                                           channelId = channel_id,
                                           maxResults = 50,
                                           pageToken = next_page_token)
        response = request.execute()
        
        for i in response['items']:
            data = dict(Playlist_ID = i['id'],
                        Title = i['snippet']['title'],
                        Channel_ID = i['snippet']['channelId'],
                        Channel_Name = i['snippet']['channelTitle'],
                        Published_Date = i['snippet']['publishedAt'],
                        Video_Count = i['contentDetails']['itemCount'])
            playlist_data.append(data)  
            
        next_page_token = response.get('nextPageToken')   
        if next_page_token is None :
             break
                
    return  playlist_data

# %%
playlist_details = get_playlist_details('UCvppRuz_VW0x2a5BEAphhNg')

# %%
len(playlist_details)
# Out:
# 18

# %%
# Uploading to MongoDB:

client = pymongo.MongoClient('mongodb+srv://Ramya:Ramyamahesh@cluster0.wuc0axa.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')
db = client['Youtube_Data']

# %%
all_channels=[]
db = client['Youtube_Data']
coll1 = db['channel_details']
for ch_data in coll1.find({},{'_id':0,'channel_information':1}):
    all_channels.append(ch_data['channel_information']['Channel_Name'])

# %%
single_ch_detail =[]
db = client['Youtube_Data']
coll1 = db['channel_details']
for ch_data in coll1.find({"channel_information.Channel_Name":"jada"},{'_id':0}):
    single_ch_detail.append(ch_data['channel_information'])

df_single_channel =pd.DataFrame(single_ch_detail)

# %%
single_pl_list = []
db = client['Youtube_Data']
coll1 = db['channel_details']
for pl_data in coll1.find({"channel_information.Channel_Name":"jada"},{'_id':0}):
        single_pl_list.append(pl_data['playlist_information'])
       
df_single_playlist = pd.DataFrame(single_pl_list)

# %%
single_cm_list = []
db = client['Youtube_Data']
coll1 = db['channel_details']
for cm_data in coll1.find({"channel_information.Channel_Name":"jada"},{'_id':0}):
        single_cm_list.append(cm_data['comment_information'])
       
df_single_comment = pd.DataFrame(single_cm_list[0])

# %%
df_single_comment
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
def channel_details(channel_id):
    ch_details = get_channel_info(channel_id)
    pl_details = get_playlist_details(channel_id)
    vd_ids = get_videos_ids(channel_id)
    vd_details = get_video_info(vd_ids)
    cm_details = get_comment_info(vd_ids)


    coll1 = db['channel_details']
    coll1.insert_one({'channel_information':ch_details,
                      'playlist_information': pl_details,
                      'video_information':vd_details,
                      'comment_information':cm_details})

    return "Upload completed successfully"

# %%
# Table Creation with MySQL DB :

def channels_table():
    mydb = mysql.connector.connect(host = "127.0.0.1",
                                   user = "root",
                                   port = "3306",
                                   password = "Ramya$125",
                                   database = "youtube")
    cursor = mydb.cursor()
    cursor
    
    drop_query = '''drop table if exists channels'''
    cursor.execute(drop_query)
    mydb.commit()
    
    try :
        create_query = '''create table if not exists channels(Channel_Name varchar(255),
                                                                  Channel_ID   varchar(255) primary key,
                                                                  Subscribers  bigint,
                                                                  Views_Count   bigint,
                                                                  Video_Count  int,
                                                                  Channel_Description text,
                                                                  Playlist_ID varchar(255))'''
        cursor.execute(create_query)
        mydb.commit()
    except :
     print('Table already created ')
    
    ch_list = []
    db = client['Youtube_Data']
    coll1 = db['channel_details']
    for ch_data in coll1.find({},{'_id':0,'channel_information':1}):
        ch_list.append(ch_data['channel_information'])
    df = pd.DataFrame(ch_list)
    
    
    for index,row in df.iterrows():
        insert_query = '''insert into channels(Channel_Name,
                                               Channel_ID,
                                               Subscribers,
                                               Views_Count,
                                               Video_Count,
                                               Channel_Description,
                                               Playlist_ID)
    
                                               values(%s,%s,%s,%s,%s,%s,%s)'''
        values = (row['Channel_Name'],
                   row['Channel_ID'],
                   row['Subscribers'],
                   row['Views_Count'],
                   row['Video_Count'],
                   row['Channel_Description'],
                   row['Playlist_ID'])
    
        try :
            cursor.execute(insert_query,values)
            mydb.commit()
    
        except :
            print("Channels values are already inserted")

# %%
def playlist_table():
    mydb = mysql.connector.connect(host = "127.0.0.1",
                                   user = "root",
                                   port = "3306",
                                   password = "Ramya$125",
                                   database = "youtube")
    cursor = mydb.cursor()
    
    
    drop_query = '''drop table if exists playlists'''
    cursor.execute(drop_query)
    mydb.commit()
    
    
    create_query = '''create table if not exists playlists(Playlist_ID varchar(255) primary key ,
                                                           Title   varchar(255),
                                                           Channel_ID varchar(255),
                                                           Channel_Name  varchar(255),
                                                           Published_Date DATETIME,
                                                           Video_Count int)'''
                                                           
    cursor.execute(create_query)
    mydb.commit()
    
    pl_list = []
    db = client['Youtube_Data']
    coll1 = db['channel_details']
    for pl_data in coll1.find({},{'_id':0,'playlist_information':1}):
        for i in range(len(pl_data['playlist_information'])):
            pl_list.append(pl_data['playlist_information'][i])
           
    df1 = pd.DataFrame(pl_list)
    
    for index,row in df1.iterrows():
        
        insert_query = '''insert into playlists(Playlist_ID,
                                               Title,
                                               Channel_ID,
                                               Channel_Name,
                                               Published_Date,
                                               Video_Count)
    
                                               values(%s,%s,%s,%s,%s,%s)'''            
                                                           
        values = (row['Playlist_ID'],
                  row['Title'],
                  row['Channel_ID'],
                  row['Channel_Name'],
                  datetime.strptime(row['Published_Date'],'%Y-%m-%dT%H:%M:%SZ'),
                  row['Video_Count'])
                                                                    
        cursor.execute(insert_query,values)
        mydb.commit()

# %%
def video_table():
    mydb = mysql.connector.connect(host = "127.0.0.1",
                                   user = "root",
                                   port = "3306",
                                   password = "Ramya$125",
                                   database = "youtube")
    cursor = mydb.cursor()
    
    drop_query = '''drop table if exists videos'''
    cursor.execute(drop_query)
    mydb.commit()
    
    create_query = '''create table if not exists videos(Channel_Name varchar(255),
                                                        Channel_ID varchar(255),
                                                        Video_ID varchar(255) primary key,
                                                        Video_Title varchar(255),
                                                        Thumbnail varchar(255),
                                                        Description text,
                                                        Published_Date DATETIME,
                                                        Duration int,
                                                        Views_Count bigint,
                                                        Likes_Count bigint,
                                                        Comments_Count int,
                                                        Favourite_Count int,
                                                        Definition varchar(255),
                                                        Caption_Status varchar(255))'''
                                                           
    cursor.execute(create_query)
    mydb.commit()
    
    vd_list = []
    db = client['Youtube_Data']
    coll1 = db['channel_details']
    for vd_data in coll1.find({},{'_id':0,'video_information':1}):
        for i in range(len(vd_data['video_information'])):
            vd_list.append(vd_data['video_information'][i])
    df2 = pd.DataFrame(vd_list)
    
    
    
    for index,row in df2.iterrows():
    
        yt_duration = row['Duration']  # Example: YouTube duration string
        duration_obj = isodate.parse_duration(yt_duration)
        standard_time = int(duration_obj.total_seconds())  # Convert to seconds
    
        
        insert_query = '''insert into videos(Channel_Name ,
                                             Channel_ID ,
                                             Video_ID ,
                                             Video_Title ,
                                             Thumbnail ,
                                             Description ,
                                             Published_Date ,
                                             Duration ,
                                             Views_Count ,
                                             Likes_Count ,
                                             Comments_Count ,
                                             Favourite_Count ,
                                             Definition ,
                                             Caption_Status )
                                                        
                                             values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''            
                                                           
        values = (row['Channel_Name'],
                  row['Channel_ID'],
                  row['Video_ID'],
                  row['Video_Title'],
                  row['Thumbnail'],
                  row['Description'],
                  datetime.strptime(row['Published_Date'],'%Y-%m-%dT%H:%M:%SZ'),
                  standard_time, 
                  row['Views_Count'],
                  row['Likes_Count'],
                  row['Comments_Count'],
                  row['Favourite_Count'],
                  row['Definition'],
                  row['Caption_Status'])
                 
                                                                    
        cursor.execute(insert_query,values)
        mydb.commit()

# %%
def comments_table():
    
    mydb = mysql.connector.connect(host = "127.0.0.1",
                                   user = "root",
                                   port = "3306",
                                   password = "Ramya$125",
                                   database = "youtube")
    cursor = mydb.cursor()
    
    
    drop_query = '''drop table if exists comments'''
    cursor.execute(drop_query)
    mydb.commit()
    
    create_query = '''create table if not exists comments(Comment_ID varchar(255) primary key ,
                                                          Video_ID   varchar(255),
                                                          Comment_Text text,
                                                          Comment_Author  varchar(255),
                                                          Comment_Published DATETIME)'''
                                                           
    cursor.execute(create_query)
    mydb.commit()
    
    cm_list = []
    db = client['Youtube_Data']
    coll1 = db['channel_details']
    for cm_data in coll1.find({},{'_id':0,'comment_information':1}):
        for i in range(len(cm_data['comment_information'])):
            cm_list.append(cm_data['comment_information'][i])
           
    df3 = pd.DataFrame(cm_list)
    
    
    for index,row in df3.iterrows():
            
            insert_query = '''insert into comments(Comment_ID ,
                                                   Video_ID  ,
                                                   Comment_Text ,
                                                   Comment_Author ,
                                                   Comment_Published)
                                                   
                                                   values(%s,%s,%s,%s,%s)'''            
                                                               
            values = (row['Comment_ID'],
                      row['Video_ID'],
                      row['Comment_Text'],
                      row['Comment_Author'],
                      datetime.strptime(row['Comment_Published'],'%Y-%m-%dT%H:%M:%SZ'))
                      
                                                                        
            cursor.execute(insert_query,values)
            mydb.commit()

# %%
def tables():
    channels_table()
    playlist_table()
    video_table()
    comments_table()

    return "tables created successfully"

# %%
mydb = mysql.connector.connect(host = "127.0.0.1",
                                   user = "root",
                                   port = "3306",
                                   password = "Ramya$125",
                                   database = "youtube")
cursor = mydb.cursor()

# %%
Tables = tables()

# %%
Tables
# Out:
# 'tables created successfully'

# %%
def show_channels_table():
    
    ch_list = []
    db = client['Youtube_Data']
    coll1 = db['channel_details']
    for ch_data in coll1.find({},{'_id':0,'channel_information':1}):
        ch_list.append(ch_data['channel_information'])
    df = st.dataframe(ch_list)

    return df

# %%
def show_playlists_table():
    
    pl_list = []
    db = client['Youtube_Data']
    coll1 = db['channel_details']
    for pl_data in coll1.find({},{'_id':0,'playlist_information':1}):
        for i in range(len(pl_data['playlist_information'])):
            pl_list.append(pl_data['playlist_information'][i])
           
    df1 = st.dataframe(pl_list)
    
    return df1

# %%
def show_videos_table():
    
    vd_list = []
    db = client['Youtube_Data']
    coll1 = db['channel_details']
    for vd_data in coll1.find({},{'_id':0,'video_information':1}):
        for i in range(len(vd_data['video_information'])):
            vd_list.append(vd_data['video_information'][i])
    df2 = st.dataframe(vd_list)
    
    return df2

# %%
def show_comments_table():
    
    cm_list = []
    db = client['Youtube_Data']
    coll1 = db['channel_details']
    for cm_data in coll1.find({},{'_id':0,'comment_information':1}):
        for i in range(len(cm_data['comment_information'])):
            cm_list.append(cm_data['comment_information'][i])
           
    df3 = st.dataframe(cm_list)
    
    return df3

# %%
# streamlit 

with st.sidebar:
    st.title(":blue[YOUTUBE DATA HARVESTING AND WAREHOUSING]")
    st.header("Skills Take Away")
    st.caption("Python Scripting")
    st.caption("API Integration")
    st.caption("Data Collection")
    st.caption("Data Management")
    st.caption("MongoDB")
    st.caption("MySQL")

channel_id = st.text_input("Enter The Channel ID")

if st.button("Collect And Store Data"):
    ch_ids = []
    db = client['Youtube_Data']
    coll1 = db['channel_details']
    for ch_data in coll1.find({},{"_id":0,"channel_information":1}):
        ch_ids.append(ch_data['channel_information']['Channel_ID'])

    if channel_id in ch_ids :
        st.success("Channel ID Already Exists ")
    else :
        insert = channel_details(channel_id)
        st.success(insert)

if st.button("Migrate To MySQL"):
    Table = tables()
    st.success(Table)

show_table = st.radio("Select The Table",("CHANNELS","PLAYLISTS","VIDEOS","COMMENTS"))

if show_table == "CHANNELS":
    show_channels_table()

elif show_table == "PLAYLISTS":
    show_playlists_table()

elif show_table == "VIDEOS":
    show_videos_table()

elif show_table == "COMMENTS":
    show_comments_table()
# Out:
# 2024-05-24 16:42:32.697
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\ramya\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]

# %%
# Connection to MySQL

mydb = mysql.connector.connect(host = "127.0.0.1",
                                   user = "root",
                                   port = "3306",
                                   password = "Ramya$125",
                                   database = "youtube")
cursor = mydb.cursor()


question = st.selectbox("Select The Question",("1. All The Videos And Channel Name",
                                               "2. Channels With Most Number Of Video",
                                               "3. Top 10 Most Viewed Vieod",
                                               "4. Comments In Each Videos",
                                               "5. Videos With Highest Likes",
                                               "6. Total Number Of Likes Of All Videos",
                                               "7. Total Number Of Views Of Each Channel",
                                               "8. Videos Published In The Year Of 2022",
                                               "9. Average Duration Of All Videos In Each Channel",
                                               "10. Videos With Highest Number Of Comments"))
                                              
if question =="1. All The Videos And Channel Name":
    query1 = ''' select Video_Title as Videos,Channel_Name as Channel_Name from videos'''
    cursor.execute(query1)
    t1 = cursor.fetchall()
    mydb.commit()
    df = pd.DataFrame(t1,columns=['video title','channel name'])
    st.write(df)

elif question =="2. Channels With Most Number Of Video":
    query2 = ''' select channel_name as Channel_name, video_count as Total_Videos from channels
                 order by video_count desc'''
    cursor.execute(query2)
    t2 = cursor.fetchall()
    mydb.commit()
    df2 = pd.DataFrame(t2,columns=['Channel Name','No of Videos'])
    st.write(df2)

elif question =="3. Top 10 Most Viewed Vieod":
    query3 = ''' select views_count as Views,channel_name as Channel_Name,video_title as Video_Title from videos
                 where views_count is not null  order by views desc limit 10'''
    cursor.execute(query3)
    t3 = cursor.fetchall()
    mydb.commit()
    df3 = pd.DataFrame(t3,columns=['Views','Channel_Name','Video_Title'])
    st.write(df3)


elif question =="4. Comments In Each Videos":
    query4 = ''' select comments_count as Comments_Count,video_title as Video_Title from videos 
                 where comments_count is not null'''
    cursor.execute(query4)
    t4 = cursor.fetchall()
    mydb.commit()
    df4 = pd.DataFrame(t4,columns=['Comments_Count','Video_Title'])
    st.write(df4)

elif question =="5. Videos With Highest Likes":
    query5 = ''' select video_title as Video_Title , channel_name as Channel_Name,likes_count as Likes_Count from videos
                where likes_count is not null order by likes_count desc'''
    cursor.execute(query5)
    t5 = cursor.fetchall()
    mydb.commit()
    df5 = pd.DataFrame(t5,columns=['Video_Title','Channel_Name','Likes_Count'])
    st.write(df5)
    
elif question =="6. Total Number Of Likes Of All Videos":
    query6 = ''' select likes_count as Likes_Count , video_title as Video_Title from videos'''
    cursor.execute(query6)
    t6 = cursor.fetchall()
    mydb.commit()
    df6 = pd.DataFrame(t6,columns=['Likes_Count','Video_Title'])
    st.write(df6)

elif question =="7. Total Number Of Views Of Each Channel":
    query7 = ''' select channel_name as Channel_Name,views_count as Views_Count from channels'''
    cursor.execute(query7)
    t7 = cursor.fetchall()
    mydb.commit()
    df7 = pd.DataFrame(t7,columns=['Channel_Name','Views_Count'])
    st.write(df7)

elif question =="8. Videos Published In The Year Of 2022":
    query8 = ''' select video_title as Video_Title,published_date as Published_At,channel_name as Channel_Name from videos
                 where extract(year from published_date)=2022 '''
    cursor.execute(query8)
    t8 = cursor.fetchall()
    mydb.commit()
    df8 = pd.DataFrame(t8,columns=['Video_Title','Published_At','Channel_Name'])
    st.write(df8)

elif question =="9. Average Duration Of All Videos In Each Channel":
    query9 = ''' select channel_name as Channel_Name , AVG (duration) as Average_Duration from videos group by channel_name '''
    cursor.execute(query9)
    t9 = cursor.fetchall()
    mydb.commit()
    df9 = pd.DataFrame(t9,columns=['Channel_Name','Average_Duration'])
    st.write(df9)

elif question =="10. Videos With Highest Number Of Comments":
    query10 = ''' select video_title as Video_Title, channel_name as Channel_Name,comments_count as Comments from videos
                  where comments_count is not null order by comments_count desc'''
    cursor.execute(query10)
    t10 = cursor.fetchall()
    mydb.commit()
    df10 = pd.DataFrame(t10,columns=['Video_Title','Channel_Name','Comments'])
    st.write(df10)

# %%
#elif question =="8. Videos Published In The Year Of 2022":
query8 = ''' select video_title as Video_Title,published_date as Published_At,channel_name as Channel_Name from videos
             where extract(year from Published_Date) = 2024 '''
cursor.execute(query8)
t8 = cursor.fetchall()
mydb.commit()
df8 = pd.DataFrame(t8,columns=['Video_Title','Published_At','Channel_Name'])
#st.write(df8)

# %%
mydb = mysql.connector.connect(host = "127.0.0.1",
                                   user = "root",
                                   port = "3306",
                                   password = "Ramya$125",
                                   database = "youtube")
cursor = mydb.cursor()

#elif question =="10. Videos With Highest Number Of Comments":
query10 = ''' select video_title as Video_Title, channel_name as Channel_Name,comments_count as Comments from videos
              where comments_count is not null order by comments_count desc'''
cursor.execute(query10)
t10 = cursor.fetchall()
mydb.commit()
df10 = pd.DataFrame(t10,columns=['Video_Title','Channel_Name','Comments'])
#st.write(df10)
